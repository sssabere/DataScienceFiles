# %% [markdown]
# # Assignment 1 for Course 1MS041
# Make sure you pass the `# ... Test` cells and
#  submit your solution notebook in the corresponding assignment on the course website. You can submit multiple times before the deadline and your highest score will be used.

# %% [markdown]
# ---
# ## Assignment 1, PROBLEM 1
# Maximum Points = 3

# %% [markdown]
# Given that you are being introduced to data science it is important to bear in mind the true costs of AI, a highly predictive family of algorithms used in data engineering sciences:
#
# Read the 16 pages of [ai-anatomy-publication.pdf](http://www.anatomyof.ai/img/ai-anatomy-publication.pdf) with the highly detailed [ai-anatomy-map.pdf](https://anatomyof.ai/img/ai-anatomy-map.pdf) of [https://anatomyof.ai/](https://anatomyof.ai/), "Anatomy of an AI System" By Kate Crawford and Vladan Joler (2018).  The first problem in ASSIGNMENT 1 is a trivial test of your reading comprehension.
#
#
# Answer whether each of the following statements is `True` or `False` *according to the authors* by appropriately replacing `Xxxxx` coresponding to `TruthValueOfStatement0a`, `TruthValueOfStatement0b` and `TruthValueOfStatement0c`, respectively, in the next cell to demonstrate your reading comprehension.
#
# 1. `Statement0a =` *Each small moment of convenience (provided by Amazon's Echo) – be it answering a question, turning on a light, or playing a song – requires a vast planetary network, fueled by the extraction of non-renewable materials, labor, and data.*
# 2. `Statement0b =` *The Echo user is simultaneously a consumer, a resource, a worker, and a product*
# 3. `Statement0c =` *Many of the assumptions about human life made by machine learning systems are narrow, normative and laden with error. Yet they are inscribing and building those assumptions into a new world, and will increasingly play a role in how opportunities, wealth, and knowledge are distributed.*

# %%
# Replace Xxxxx with True or False; Don't modify anything else in this cell!

TruthValueOfStatement0a = True

TruthValueOfStatement0b = True

TruthValueOfStatement0c = True

# %% [markdown]
# ---
# #### Local Test for Assignment 1, PROBLEM 1
# Evaluate cell below to make sure your answer is valid.                             You **should not** modify anything in the cell below when evaluating it to do a local test of                             your solution.
# You may need to include and evaluate code snippets from lecture notebooks in cells above to make the local test work correctly sometimes (see error messages for clues). This is meant to help you become efficient at recalling materials covered in lectures that relate to this problem. Such local tests will generally not be available in the exam.

# %%
# Test locally to ensure an acceptable answer, True or False
try:
    assert(isinstance(TruthValueOfStatement0a, bool)) 
    assert(isinstance(TruthValueOfStatement0b, bool)) 
    assert(isinstance(TruthValueOfStatement0c, bool))
except:
    print("Try again. You are not writing True or False for your answers.")
else:
    print("Good, you have answered either True or False. Hopefully they are the correct answers!")
# Out:
# Good, you have answered either True or False. Hopefully they are the correct answers!

# %% [markdown]
# ---
# ## Assignment 1, PROBLEM 2
# Maximum Points = 2

# %% [markdown]
# Evaluate the following cells by replacing `X` with the right command-line option to `head` in order to find the first four lines of the csv file `data/final.csv`
#
# ```
# %%sh
# man head
#
# HEAD(1)                   BSD General Commands Manual                  HEAD(1)
#
# NAME
#      head -- display first lines of a file
#
# SYNOPSIS
#      head [-n count | -c bytes] [file ...]
#
# DESCRIPTION
#      This filter displays the first count lines or bytes of each of the speci-
#      fied files, or of the standard input if no files are specified.  If count
#      is omitted it defaults to 10.
#
#      If more than a single file is specified, each file is preceded by a
#      header consisting of the string ``==> XXX <=='' where ``XXX'' is the name
#      of the file.
#
# EXIT STATUS
#      The head utility exits 0 on success, and >0 if an error occurs.
#
# SEE ALSO
#      tail(1)
#
# HISTORY
#      The head command appeared in PWB UNIX.
#
# BSD                              June 6, 1993                              BSD
# ```

# %%
# %%sh
# head -n 4 first_lecture_and_data/data/final.csv
# Out:
# region,municipality,district,party,votes
# Blekinge län,Karlshamn,0 - Centrala Asarum,S,519
# Blekinge län,Karlshamn,0 - Centrala Asarum,SD,311
# Blekinge län,Karlshamn,0 - Centrala Asarum,M,162

# %%
line_1_final = "region,municipality,district,party,votes"
line_2_final = "Blekinge län,Karlshamn,0 - Centrala Asarum,S,519"

# %% [markdown]
# ---
# #### Local Test for Assignment 1, PROBLEM 2
# Evaluate cell below to make sure your answer is valid.                             You **should not** modify anything in the cell below when evaluating it to do a local test of                             your solution.
# You may need to include and evaluate code snippets from lecture notebooks in cells above to make the local test work correctly sometimes (see error messages for clues). This is meant to help you become efficient at recalling materials covered in lectures that relate to this problem. Such local tests will generally not be available in the exam.

# %%
# Evaluate this cell locally to make sure you have the answer as a string
try:
    assert(type(line_1_final) == str)
    print("Good! You have answered as a string for line 1. Hopefully it is the correct!")
except AssertionError:
    print("Try Again. You should answer with a string.")
try:
    assert(type(line_2_final) == str)
    print("Good! You have answered as a string for line 2. Hopefully it is the correct!")
except AssertionError:
    print("Try Again. You should answer with a string.")
# Out:
# Good! You have answered as a string for line 1. Hopefully it is the correct!
# Good! You have answered as a string for line 2. Hopefully it is the correct!

# %% [markdown]
# ---
# ## Assignment 1, PROBLEM 3
# Maximum Points = 3

# %% [markdown]
# In this assignment the goal is to parse the `final.csv` file from the previous problem.
#
# 1. Read the file `data/final.csv` and parse it using the `csv` package and store the result as follows
#
# the `header` variable contains a list of names all as strings
#
# the `data` variable should be a list of lists containing all the rows of the csv file

# %%
import csv
import numpy as np
csv_file = open('first_lecture_and_data/data/final.csv')
csv_reader = csv.reader(csv_file)
header = next(csv_reader)
data = [row for row in csv_reader]
data
# Out:
# [['Blekinge län', 'Karlshamn', '0 - Centrala Asarum', 'S', '519'],
#  ['Blekinge län', 'Karlshamn', '0 - Centrala Asarum', 'SD', '311'],
#  ['Blekinge län', 'Karlshamn', '0 - Centrala Asarum', 'M', '162'],
#  ['Blekinge län', 'Karlshamn', '0 - Centrala Asarum', 'V', '82'],
#  ['Blekinge län', 'Karlshamn', '0 - Centrala Asarum', 'KD', '53'],
#  ['Blekinge län', 'Karlshamn', '0 - Centrala Asarum', 'C', '37'],
#  ['Blekinge län', 'Karlshamn', '0 - Centrala Asarum', 'L', '37'],
#  ['Blekinge län', 'Karlshamn', '0 - Centrala Asarum', 'MP', '32'],
#  ['Blekinge län', 'Karlshamn', '0 - Centrala Asarum', 'BLANK', '13'],
#  ['Blekinge län', 'Karlshamn', '0 - Centrala Asarum', 'ÖVR', '11'],
#  ['Blekinge län', 'Karlshamn', '0 - Centrala Asarum', 'FI', '8'],
#  ['Blekinge län', 'Karlshamn', '0 - Centrala Asarum', 'OGEJ', '0'],
#  ['Blekinge län', 'Karlshamn', '0 - Centrala Asarum', 'OG', '0'],
#  ['Blekinge län', 'Karlshamn', '10 - Skogsborg', 'S', '289'],
#  ['Blekinge län', 'Karlshamn', '10 - Skogsborg', 'M', '237'],
#  ['Blekinge län', 'Karlshamn', '10 - Skogsborg', 'SD', '176'],
#  ['Blekinge län', 'Karlshamn', '10 - Skogsborg', 'V', '75'],
#  ['Blekinge län', 'Karlshamn', '10 - Skogsborg', 'MP', '63'],
#  ['Blekinge län', 'Karlshamn', '10 - Skogsborg', 'L', '53'],
#  ['Blekinge län', 'Karlshamn', '10 - Skogsborg', 'C', '51'],
#  ['Blekinge län', 'Karlshamn', '10 - Skogsborg', 'KD', '44'],
#  ['Blekinge län', 'Karlshamn', '10 - Skogsborg', 'BLANK', '13'],
#  ['Blekinge län', 'Karlshamn', '10 - Skogsborg', 'ÖVR', '8'],
#  ['Blekinge län', 'Karlshamn', '10 - Skogsborg', 'FI', '5'],
#  ['Blekinge län', 'Karlshamn', '10 - Skogsborg', 'OGEJ', '2'],
#  ['Blekinge län', 'Karlshamn', '10 - Skogsborg', 'OG', '0'],
#  ['Blekinge län', 'Karlshamn', '11 - Stadsporten', 'S', '395'],
#  ['Blekinge län', 'Karlshamn', '11 - Stadsporten', 'SD', '289'],
#  ['Blekinge län', 'Karlshamn', '11 - Stadsporten', 'M', '217'],
#  ['Blekinge län', 'Karlshamn', '11 - Stadsporten', 'V', '73'],
#  ['Blekinge län', 'Karlshamn', '11 - Stadsporten', 'C', '57'],
#  ['Blekinge län', 'Karlshamn', '11 - Stadsporten', 'KD', '53'],
#  ['Blekinge län', 'Karlshamn', '11 - Stadsporten', 'L', '40'],
#  ['Blekinge län', 'Karlshamn', '11 - Stadsporten', 'MP', '35'],
#  ['Blekinge län', 'Karlshamn', '11 - Stadsporten', 'BLANK', '17'],
#  ['Blekinge län', 'Karlshamn', '11 - Stadsporten', 'FI', '4'],
#  ['Blekinge län', 'Karlshamn', '11 - Stadsporten', 'ÖVR', '4'],
#  ['Blekinge län', 'Karlshamn', '11 - Stadsporten', 'OG', '1'],
#  ['Blekinge län', 'Karlshamn', '11 - Stadsporten', 'OGEJ', '0'],
#  ['Blekinge län', 'Karlshamn', '12 - Svängsta nordöst', 'S', '402'],
#  ['Blekinge län', 'Karlshamn', '12 - Svängsta nordöst', 'SD', '360'],
#  ['Blekinge län', 'Karlshamn', '12 - Svängsta nordöst', 'M', '128'],
#  ['Blekinge län', 'Karlshamn', '12 - Svängsta nordöst', 'C', '98'],
#  ['Blekinge län', 'Karlshamn', '12 - Svängsta nordöst', 'KD', '63'],
#  ['Blekinge län', 'Karlshamn', '12 - Svängsta nordöst', 'V', '62'],
#  ['Blekinge län', 'Karlshamn', '12 - Svängsta nordöst', 'BLANK', '20'],
#  ['Blekinge län', 'Karlshamn', '12 - Svängsta nordöst', 'MP', '19'],
#  ['Blekinge län', 'Karlshamn', '12 - Svängsta nordöst', 'L', '18'],
#  ['Blekinge län', 'Karlshamn', '12 - Svängsta nordöst', 'ÖVR', '12'],
#  ['Blekinge län', 'Karlshamn', '12 - Svängsta nordöst', 'FI', '1'],
#  ['Blekinge län', 'Karlshamn', '12 - Svängsta nordöst', 'OG', '1'],
#  ['Blekinge län', 'Karlshamn', '12 - Svängsta nordöst', 'OGEJ', '0'],
#  ['Blekinge län', 'Karlshamn', '13 - Svängsta sydväst', 'SD', '334'],
#  ['Blekinge län', 'Karlshamn', '13 - Svängsta sydväst', 'S', '256'],
#  ['Blekinge län', 'Karlshamn', '13 - Svängsta sydväst', 'M', '101'],
#  ['Blekinge län', 'Karlshamn', '13 - Svängsta sydväst', 'C', '75'],
#  ['Blekinge län', 'Karlshamn', '13 - Svängsta sydväst', 'V', '40'],
#  ['Blekinge län', 'Karlshamn', '13 - Svängsta sydväst', 'KD', '35'],
#  ['Blekinge län', 'Karlshamn', '13 - Svängsta sydväst', 'MP', '17'],
#  ['Blekinge län', 'Karlshamn', '13 - Svängsta sydväst', 'L', '12'],
#  ['Blekinge län', 'Karlshamn', '13 - Svängsta sydväst', 'BLANK', '11'],
#  ['Blekinge län', 'Karlshamn', '13 - Svängsta sydväst', 'ÖVR', '6'],
#  ['Blekinge län', 'Karlshamn', '13 - Svängsta sydväst', 'FI', '3'],
#  ['Blekinge län', 'Karlshamn', '13 - Svängsta sydväst', 'OGEJ', '0'],
#  ['Blekinge län', 'Karlshamn', '13 - Svängsta sydväst', 'OG', '0'],
#  ['Blekinge län', 'Karlshamn', '14 - Torget', 'S', '372'],
#  ['Blekinge län', 'Karlshamn', '14 - Torget', 'M', '268'],
#  ['Blekinge län', 'Karlshamn', '14 - Torget', 'SD', '250'],
#  ['Blekinge län', 'Karlshamn', '14 - Torget', 'V', '96'],
#  ['Blekinge län', 'Karlshamn', '14 - Torget', 'KD', '70'],
#  ['Blekinge län', 'Karlshamn', '14 - Torget', 'C', '61'],
#  ['Blekinge län', 'Karlshamn', '14 - Torget', 'L', '48'],
#  ['Blekinge län', 'Karlshamn', '14 - Torget', 'MP', '43'],
#  ['Blekinge län', 'Karlshamn', '14 - Torget', 'ÖVR', '14'],
#  ['Blekinge län', 'Karlshamn', '14 - Torget', 'BLANK', '9'],
#  ['Blekinge län', 'Karlshamn', '14 - Torget', 'FI', '7'],
#  ['Blekinge län', 'Karlshamn', '14 - Torget', 'OGEJ', '1'],
#  ['Blekinge län', 'Karlshamn', '14 - Torget', 'OG', '0'],
#  ['Blekinge län', 'Karlshamn', '15 - Tubbaryd', 'S', '329'],
#  ['Blekinge län', 'Karlshamn', '15 - Tubbaryd', 'SD', '214'],
#  ['Blekinge län', 'Karlshamn', '15 - Tubbaryd', 'M', '149'],
#  ['Blekinge län', 'Karlshamn', '15 - Tubbaryd', 'V', '78'],
#  ['Blekinge län', 'Karlshamn', '15 - Tubbaryd', 'C', '59'],
#  ['Blekinge län', 'Karlshamn', '15 - Tubbaryd', 'L', '39'],
#  ['Blekinge län', 'Karlshamn', '15 - Tubbaryd', 'KD', '39'],
#  ['Blekinge län', 'Karlshamn', '15 - Tubbaryd', 'MP', '39'],
#  ['Blekinge län', 'Karlshamn', '15 - Tubbaryd', 'ÖVR', '13'],
#  ['Blekinge län', 'Karlshamn', '15 - Tubbaryd', 'FI', '10'],
#  ['Blekinge län', 'Karlshamn', '15 - Tubbaryd', 'BLANK', '9'],
#  ['Blekinge län', 'Karlshamn', '15 - Tubbaryd', 'OGEJ', '0'],
#  ['Blekinge län', 'Karlshamn', '15 - Tubbaryd', 'OG', '0'],
#  ['Blekinge län', 'Karlshamn', '16 - Vägga', 'S', '405'],
#  ['Blekinge län', 'Karlshamn', '16 - Vägga', 'M', '279'],
#  ['Blekinge län', 'Karlshamn', '16 - Vägga', 'SD', '252'],
#  ['Blekinge län', 'Karlshamn', '16 - Vägga', 'C', '100'],
#  ['Blekinge län', 'Karlshamn', '16 - Vägga', 'KD', '93'],
#  ['Blekinge län', 'Karlshamn', '16 - Vägga', 'V', '74'],
#  ['Blekinge län', 'Karlshamn', '16 - Vägga', 'MP', '72'],
#  ['Blekinge län', 'Karlshamn', '16 - Vägga', 'L', '69'],
#  ['Blekinge län', 'Karlshamn', '16 - Vägga', 'ÖVR', '13'],
#  ['Blekinge län', 'Karlshamn', '16 - Vägga', 'BLANK', '11'],
#  ['Blekinge län', 'Karlshamn', '16 - Vägga', 'FI', '7'],
#  ['Blekinge län', 'Karlshamn', '16 - Vägga', 'OGEJ', '0'],
#  ['Blekinge län', 'Karlshamn', '16 - Vägga', 'OG', '0'],
#  ['Blekinge län', 'Karlshamn', '17 - Österslätt', 'S', '299'],
#  ['Blekinge län', 'Karlshamn', '17 - Österslätt', 'M', '228'],
#  ['Blekinge län', 'Karlshamn', '17 - Österslätt', 'SD', '189'],
#  ['Blekinge län', 'Karlshamn', '17 - Österslätt', 'V', '93'],
#  ['Blekinge län', 'Karlshamn', '17 - Österslätt', 'KD', '57'],
#  ['Blekinge län', 'Karlshamn', '17 - Österslätt', 'C', '56'],
#  ['Blekinge län', 'Karlshamn', '17 - Österslätt', 'L', '53'],
#  ['Blekinge län', 'Karlshamn', '17 - Österslätt', 'MP', '32'],
#  ['Blekinge län', 'Karlshamn', '17 - Österslätt', 'BLANK', '11'],
#  ['Blekinge län', 'Karlshamn', '17 - Österslätt', 'ÖVR', '8'],
#  ['Blekinge län', 'Karlshamn', '17 - Österslätt', 'FI', '2'],
#  ['Blekinge län', 'Karlshamn', '17 - Österslätt', 'OGEJ', '0'],
#  ['Blekinge län', 'Karlshamn', '17 - Österslätt', 'OG', '0'],
#  ['Blekinge län', 'Karlshamn', '18 - Uppsamlingsdistrikt', 'S', '129'],
#  ['Blekinge län', 'Karlshamn', '18 - Uppsamlingsdistrikt', 'M', '109'],
#  ['Blekinge län', 'Karlshamn', '18 - Uppsamlingsdistrikt', 'SD', '97'],
#  ['Blekinge län', 'Karlshamn', '18 - Uppsamlingsdistrikt', 'V', '47'],
#  ['Blekinge län', 'Karlshamn', '18 - Uppsamlingsdistrikt', 'MP', '40'],
#  ['Blekinge län', 'Karlshamn', '18 - Uppsamlingsdistrikt', 'C', '30'],
#  ['Blekinge län', 'Karlshamn', '18 - Uppsamlingsdistrikt', 'L', '17'],
#  ['Blekinge län', 'Karlshamn', '18 - Uppsamlingsdistrikt', 'KD', '17'],
#  ['Blekinge län', 'Karlshamn', '18 - Uppsamlingsdistrikt', 'ÖVR', '13'],
#  ['Blekinge län', 'Karlshamn', '18 - Uppsamlingsdistrikt', 'FI', '4'],
#  ['Blekinge län', 'Karlshamn', '18 - Uppsamlingsdistrikt', 'BLANK', '3'],
#  ['Blekinge län', 'Karlshamn', '18 - Uppsamlingsdistrikt', 'OG', '2'],
#  ['Blekinge län', 'Karlshamn', '18 - Uppsamlingsdistrikt', 'OGEJ', '0'],
#  ['Blekinge län', 'Karlshamn', '1 - Froarp', 'S', '465'],
#  ['Blekinge län', 'Karlshamn', '1 - Froarp', 'SD', '420'],
#  ['Blekinge län', 'Karlshamn', '1 - Froarp', 'M', '258'],
#  ['Blekinge län', 'Karlshamn', '1 - Froarp', 'C', '97'],
#  ['Blekinge län', 'Karlshamn', '1 - Froarp', 'V', '85'],
#  ['Blekinge län', 'Karlshamn', '1 - Froarp', 'KD', '62'],
#  ['Blekinge län', 'Karlshamn', '1 - Froarp', 'MP', '52'],
#  ['Blekinge län', 'Karlshamn', '1 - Froarp', 'L', '40'],
#  ['Blekinge län', 'Karlshamn', '1 - Froarp', 'ÖVR', '11'],
#  ['Blekinge län', 'Karlshamn', '1 - Froarp', 'FI', '8'],
#  ['Blekinge län', 'Karlshamn', '1 - Froarp', 'BLANK', '7'],
#  ['Blekinge län', 'Karlshamn', '1 - Froarp', 'OG', '1'],
#  ['Blekinge län', 'Karlshamn', '1 - Froarp', 'OGEJ', '0'],
#  ['Blekinge län', 'Karlshamn', '2 - Gustavstorp', 'S', '334'],
#  ['Blekinge län', 'Karlshamn', '2 - Gustavstorp', 'SD', '285'],
#  ['Blekinge län', 'Karlshamn', '2 - Gustavstorp', 'M', '111'],
#  ['Blekinge län', 'Karlshamn', '2 - Gustavstorp', 'C', '57'],
#  ['Blekinge län', 'Karlshamn', '2 - Gustavstorp', 'KD', '52'],
#  ['Blekinge län', 'Karlshamn', '2 - Gustavstorp', 'V', '37'],
#  ['Blekinge län', 'Karlshamn', '2 - Gustavstorp', 'L', '30'],
#  ['Blekinge län', 'Karlshamn', '2 - Gustavstorp', 'MP', '18'],
#  ['Blekinge län', 'Karlshamn', '2 - Gustavstorp', 'ÖVR', '10'],
#  ['Blekinge län', 'Karlshamn', '2 - Gustavstorp', 'BLANK', '7'],
#  ['Blekinge län', 'Karlshamn', '2 - Gustavstorp', 'OG', '2'],
#  ['Blekinge län', 'Karlshamn', '2 - Gustavstorp', 'FI', '1'],
#  ['Blekinge län', 'Karlshamn', '2 - Gustavstorp', 'OGEJ', '1'],
#  ['Blekinge län', 'Karlshamn', '3 - Horsaryd', 'S', '498'],
#  ['Blekinge län', 'Karlshamn', '3 - Horsaryd', 'SD', '397'],
#  ['Blekinge län', 'Karlshamn', '3 - Horsaryd', 'M', '224'],
#  ['Blekinge län', 'Karlshamn', '3 - Horsaryd', 'C', '87'],
#  ['Blekinge län', 'Karlshamn', '3 - Horsaryd', 'V', '86'],
#  ['Blekinge län', 'Karlshamn', '3 - Horsaryd', 'KD', '70'],
#  ['Blekinge län', 'Karlshamn', '3 - Horsaryd', 'MP', '51'],
#  ['Blekinge län', 'Karlshamn', '3 - Horsaryd', 'L', '41'],
#  ['Blekinge län', 'Karlshamn', '3 - Horsaryd', 'BLANK', '18'],
#  ['Blekinge län', 'Karlshamn', '3 - Horsaryd', 'ÖVR', '12'],
#  ['Blekinge län', 'Karlshamn', '3 - Horsaryd', 'FI', '6'],
#  ['Blekinge län', 'Karlshamn', '3 - Horsaryd', 'OGEJ', '0'],
#  ['Blekinge län', 'Karlshamn', '3 - Horsaryd', 'OG', '0'],
#  ['Blekinge län', 'Karlshamn', '4 - Hällaryd', 'SD', '442'],
#  ['Blekinge län', 'Karlshamn', '4 - Hällaryd', 'S', '381'],
#  ['Blekinge län', 'Karlshamn', '4 - Hällaryd', 'M', '222'],
#  ['Blekinge län', 'Karlshamn', '4 - Hällaryd', 'C', '190'],
#  ['Blekinge län', 'Karlshamn', '4 - Hällaryd', 'KD', '86'],
#  ['Blekinge län', 'Karlshamn', '4 - Hällaryd', 'V', '71'],
#  ['Blekinge län', 'Karlshamn', '4 - Hällaryd', 'MP', '37'],
#  ['Blekinge län', 'Karlshamn', '4 - Hällaryd', 'L', '33'],
#  ['Blekinge län', 'Karlshamn', '4 - Hällaryd', 'BLANK', '20'],
#  ['Blekinge län', 'Karlshamn', '4 - Hällaryd', 'ÖVR', '12'],
#  ['Blekinge län', 'Karlshamn', '4 - Hällaryd', 'FI', '10'],
#  ['Blekinge län', 'Karlshamn', '4 - Hällaryd', 'OGEJ', '0'],
#  ['Blekinge län', 'Karlshamn', '4 - Hällaryd', 'OG', '0'],
#  ['Blekinge län', 'Karlshamn', '5 - Högadal', 'S', '377'],
#  ['Blekinge län', 'Karlshamn', '5 - Högadal', 'SD', '214'],
#  ['Blekinge län', 'Karlshamn', '5 - Högadal', 'M', '196'],
#  ['Blekinge län', 'Karlshamn', '5 - Högadal', 'V', '80'],
#  ['Blekinge län', 'Karlshamn', '5 - Högadal', 'C', '55'],
#  ['Blekinge län', 'Karlshamn', '5 - Högadal', 'KD', '54'],
#  ['Blekinge län', 'Karlshamn', '5 - Högadal', 'L', '44'],
#  ['Blekinge län', 'Karlshamn', '5 - Högadal', 'MP', '42'],
#  ['Blekinge län', 'Karlshamn', '5 - Högadal', 'FI', '9'],
#  ['Blekinge län', 'Karlshamn', '5 - Högadal', 'ÖVR', '9'],
#  ['Blekinge län', 'Karlshamn', '5 - Högadal', 'BLANK', '7'],
#  ['Blekinge län', 'Karlshamn', '5 - Högadal', 'OGEJ', '0'],
#  ['Blekinge län', 'Karlshamn', '5 - Högadal', 'OG', '0'],
#  ['Blekinge län', 'Karlshamn', '6 - Korpadalen', 'S', '388'],
#  ['Blekinge län', 'Karlshamn', '6 - Korpadalen', 'M', '244'],
#  ['Blekinge län', 'Karlshamn', '6 - Korpadalen', 'SD', '202'],
#  ['Blekinge län', 'Karlshamn', '6 - Korpadalen', 'KD', '77'],
#  ['Blekinge län', 'Karlshamn', '6 - Korpadalen', 'C', '65'],
#  ['Blekinge län', 'Karlshamn', '6 - Korpadalen', 'V', '58'],
#  ['Blekinge län', 'Karlshamn', '6 - Korpadalen', 'L', '49'],
#  ['Blekinge län', 'Karlshamn', '6 - Korpadalen', 'MP', '44'],
#  ['Blekinge län', 'Karlshamn', '6 - Korpadalen', 'BLANK', '16'],
#  ['Blekinge län', 'Karlshamn', '6 - Korpadalen', 'ÖVR', '8'],
#  ['Blekinge län', 'Karlshamn', '6 - Korpadalen', 'FI', '3'],
#  ['Blekinge län', 'Karlshamn', '6 - Korpadalen', 'OGEJ', '0'],
#  ['Blekinge län', 'Karlshamn', '6 - Korpadalen', 'OG', '0'],
#  ['Blekinge län', 'Karlshamn', '7 - Mörrum västra', 'S', '344'],
#  ['Blekinge län', 'Karlshamn', '7 - Mörrum västra', 'SD', '286'],
#  ['Blekinge län', 'Karlshamn', '7 - Mörrum västra', 'M', '109'],
#  ['Blekinge län', 'Karlshamn', '7 - Mörrum västra', 'C', '64'],
#  ['Blekinge län', 'Karlshamn', '7 - Mörrum västra', 'KD', '63'],
#  ['Blekinge län', 'Karlshamn', '7 - Mörrum västra', 'V', '62'],
#  ['Blekinge län', 'Karlshamn', '7 - Mörrum västra', 'MP', '18'],
#  ['Blekinge län', 'Karlshamn', '7 - Mörrum västra', 'L', '15'],
#  ['Blekinge län', 'Karlshamn', '7 - Mörrum västra', 'ÖVR', '14'],
#  ['Blekinge län', 'Karlshamn', '7 - Mörrum västra', 'BLANK', '9'],
#  ['Blekinge län', 'Karlshamn', '7 - Mörrum västra', 'FI', '4'],
#  ['Blekinge län', 'Karlshamn', '7 - Mörrum västra', 'OG', '1'],
#  ['Blekinge län', 'Karlshamn', '7 - Mörrum västra', 'OGEJ', '0'],
#  ['Blekinge län', 'Karlshamn', '8 - Mörrum östra', 'S', '487'],
#  ['Blekinge län', 'Karlshamn', '8 - Mörrum östra', 'SD', '263'],
#  ['Blekinge län', 'Karlshamn', '8 - Mörrum östra', 'M', '173'],
#  ['Blekinge län', 'Karlshamn', '8 - Mörrum östra', 'C', '78'],
#  ['Blekinge län', 'Karlshamn', '8 - Mörrum östra', 'V', '42'],
#  ['Blekinge län', 'Karlshamn', '8 - Mörrum östra', 'KD', '39'],
#  ['Blekinge län', 'Karlshamn', '8 - Mörrum östra', 'L', '33'],
#  ['Blekinge län', 'Karlshamn', '8 - Mörrum östra', 'MP', '16'],
#  ['Blekinge län', 'Karlshamn', '8 - Mörrum östra', 'BLANK', '13'],
#  ['Blekinge län', 'Karlshamn', '8 - Mörrum östra', 'FI', '2'],
#  ['Blekinge län', 'Karlshamn', '8 - Mörrum östra', 'ÖVR', '1'],
#  ['Blekinge län', 'Karlshamn', '8 - Mörrum östra', 'OGEJ', '0'],
#  ['Blekinge län', 'Karlshamn', '8 - Mörrum östra', 'OG', '0'],
#  ['Blekinge län', 'Karlshamn', '9 - Prästslätten', 'S', '404'],
#  ['Blekinge län', 'Karlshamn', '9 - Prästslätten', 'SD', '237'],
#  ['Blekinge län', 'Karlshamn', '9 - Prästslätten', 'M', '217'],
#  ['Blekinge län', 'Karlshamn', '9 - Prästslätten', 'C', '75'],
#  ['Blekinge län', 'Karlshamn', '9 - Prästslätten', 'KD', '68'],
#  ['Blekinge län', 'Karlshamn', '9 - Prästslätten', 'V', '65'],
#  ['Blekinge län', 'Karlshamn', '9 - Prästslätten', 'L', '56'],
#  ['Blekinge län', 'Karlshamn', '9 - Prästslätten', 'MP', '48'],
#  ['Blekinge län', 'Karlshamn', '9 - Prästslätten', 'BLANK', '12'],
#  ['Blekinge län', 'Karlshamn', '9 - Prästslätten', 'ÖVR', '4'],
#  ['Blekinge län', 'Karlshamn', '9 - Prästslätten', 'OG', '2'],
#  ['Blekinge län', 'Karlshamn', '9 - Prästslätten', 'FI', '1'],
#  ['Blekinge län', 'Karlshamn', '9 - Prästslätten', 'OGEJ', '1'],
#  ['Blekinge län', 'Karlskrona', '10 - Saltö-Björkholmen', 'S', '373'],
#  ['Blekinge län', 'Karlskrona', '10 - Saltö-Björkholmen', 'M', '319'],
#  ['Blekinge län', 'Karlskrona', '10 - Saltö-Björkholmen', 'SD', '218'],
#  ['Blekinge län', 'Karlskrona', '10 - Saltö-Björkholmen', 'V', '112'],
#  ['Blekinge län', 'Karlskrona', '10 - Saltö-Björkholmen', 'L', '95'],
#  ['Blekinge län', 'Karlskrona', '10 - Saltö-Björkholmen', 'C', '89'],
#  ['Blekinge län', 'Karlskrona', '10 - Saltö-Björkholmen', 'KD', '68'],
#  ['Blekinge län', 'Karlskrona', '10 - Saltö-Björkholmen', 'MP', '53'],
#  ['Blekinge län', 'Karlskrona', '10 - Saltö-Björkholmen', 'ÖVR', '15'],
#  ['Blekinge län', 'Karlskrona', '10 - Saltö-Björkholmen', 'BLANK', '6'],
#  ['Blekinge län', 'Karlskrona', '10 - Saltö-Björkholmen', 'FI', '5'],
#  ['Blekinge län', 'Karlskrona', '10 - Saltö-Björkholmen', 'OGEJ', '0'],
#  ['Blekinge län', 'Karlskrona', '10 - Saltö-Björkholmen', 'OG', '0'],
#  ['Blekinge län', 'Karlskrona', '11 - Trossö Ö', 'S', '283'],
#  ['Blekinge län', 'Karlskrona', '11 - Trossö Ö', 'M', '212'],
#  ['Blekinge län', 'Karlskrona', '11 - Trossö Ö', 'SD', '204'],
#  ['Blekinge län', 'Karlskrona', '11 - Trossö Ö', 'V', '86'],
#  ['Blekinge län', 'Karlskrona', '11 - Trossö Ö', 'C', '66'],
#  ['Blekinge län', 'Karlskrona', '11 - Trossö Ö', 'KD', '66'],
#  ['Blekinge län', 'Karlskrona', '11 - Trossö Ö', 'L', '59'],
#  ['Blekinge län', 'Karlskrona', '11 - Trossö Ö', 'MP', '39'],
#  ['Blekinge län', 'Karlskrona', '11 - Trossö Ö', 'ÖVR', '20'],
#  ['Blekinge län', 'Karlskrona', '11 - Trossö Ö', 'BLANK', '9'],
#  ['Blekinge län', 'Karlskrona', '11 - Trossö Ö', 'FI', '3'],
#  ['Blekinge län', 'Karlskrona', '11 - Trossö Ö', 'OG', '1'],
#  ['Blekinge län', 'Karlskrona', '11 - Trossö Ö', 'OGEJ', '0'],
#  ['Blekinge län', 'Karlskrona', '12 - Wachtmeister m.fl.', 'S', '375'],
#  ['Blekinge län', 'Karlskrona', '12 - Wachtmeister m.fl.', 'M', '262'],
#  ['Blekinge län', 'Karlskrona', '12 - Wachtmeister m.fl.', 'SD', '189'],
#  ['Blekinge län', 'Karlskrona', '12 - Wachtmeister m.fl.', 'C', '91'],
#  ['Blekinge län', 'Karlskrona', '12 - Wachtmeister m.fl.', 'V', '84'],
#  ['Blekinge län', 'Karlskrona', '12 - Wachtmeister m.fl.', 'KD', '83'],
#  ['Blekinge län', 'Karlskrona', '12 - Wachtmeister m.fl.', 'L', '75'],
#  ['Blekinge län', 'Karlskrona', '12 - Wachtmeister m.fl.', 'MP', '53'],
#  ['Blekinge län', 'Karlskrona', '12 - Wachtmeister m.fl.', 'ÖVR', '17'],
#  ['Blekinge län', 'Karlskrona', '12 - Wachtmeister m.fl.', 'BLANK', '10'],
#  ['Blekinge län', 'Karlskrona', '12 - Wachtmeister m.fl.', 'FI', '7'],
#  ['Blekinge län', 'Karlskrona', '12 - Wachtmeister m.fl.', 'OGEJ', '0'],
#  ['Blekinge län', 'Karlskrona', '12 - Wachtmeister m.fl.', 'OG', '0'],
#  ['Blekinge län', 'Karlskrona', '13 - Västerudd', 'S', '383'],
#  ['Blekinge län', 'Karlskrona', '13 - Västerudd', 'M', '281'],
#  ['Blekinge län', 'Karlskrona', '13 - Västerudd', 'SD', '237'],
#  ['Blekinge län', 'Karlskrona', '13 - Västerudd', 'V', '91'],
#  ['Blekinge län', 'Karlskrona', '13 - Västerudd', 'L', '78'],
#  ['Blekinge län', 'Karlskrona', '13 - Västerudd', 'C', '73'],
#  ['Blekinge län', 'Karlskrona', '13 - Västerudd', 'KD', '71'],
#  ['Blekinge län', 'Karlskrona', '13 - Västerudd', 'MP', '53'],
#  ['Blekinge län', 'Karlskrona', '13 - Västerudd', 'BLANK', '16'],
#  ['Blekinge län', 'Karlskrona', '13 - Västerudd', 'ÖVR', '11'],
#  ['Blekinge län', 'Karlskrona', '13 - Västerudd', 'FI', '7'],
#  ['Blekinge län', 'Karlskrona', '13 - Västerudd', 'OG', '1'],
#  ['Blekinge län', 'Karlskrona', '13 - Västerudd', 'OGEJ', '0'],
#  ['Blekinge län', 'Karlskrona', '14 - Uppsamlingsdistrikt', 'S', '73'],
#  ['Blekinge län', 'Karlskrona', '14 - Uppsamlingsdistrikt', 'M', '63'],
#  ['Blekinge län', 'Karlskrona', '14 - Uppsamlingsdistrikt', 'SD', '47'],
#  ['Blekinge län', 'Karlskrona', '14 - Uppsamlingsdistrikt', 'C', '42'],
#  ['Blekinge län', 'Karlskrona', '14 - Uppsamlingsdistrikt', 'V', '32'],
#  ['Blekinge län', 'Karlskrona', '14 - Uppsamlingsdistrikt', 'L', '30'],
#  ['Blekinge län', 'Karlskrona', '14 - Uppsamlingsdistrikt', 'MP', '26'],
#  ['Blekinge län', 'Karlskrona', '14 - Uppsamlingsdistrikt', 'KD', '21'],
#  ['Blekinge län', 'Karlskrona', '14 - Uppsamlingsdistrikt', 'ÖVR', '11'],
#  ['Blekinge län', 'Karlskrona', '14 - Uppsamlingsdistrikt', 'FI', '8'],
#  ['Blekinge län', 'Karlskrona', '14 - Uppsamlingsdistrikt', 'BLANK', '5'],
#  ['Blekinge län', 'Karlskrona', '14 - Uppsamlingsdistrikt', 'OGEJ', '0'],
#  ['Blekinge län', 'Karlskrona', '14 - Uppsamlingsdistrikt', 'OG', '0'],
#  ['Blekinge län', 'Karlskrona', '16 - Fridlevstad', 'SD', '361'],
#  ['Blekinge län', 'Karlskrona', '16 - Fridlevstad', 'S', '283'],
#  ['Blekinge län', 'Karlskrona', '16 - Fridlevstad', 'M', '127'],
#  ['Blekinge län', 'Karlskrona', '16 - Fridlevstad', 'KD', '64'],
#  ['Blekinge län', 'Karlskrona', '16 - Fridlevstad', 'C', '60'],
#  ['Blekinge län', 'Karlskrona', '16 - Fridlevstad', 'V', '39'],
#  ['Blekinge län', 'Karlskrona', '16 - Fridlevstad', 'L', '37'],
#  ['Blekinge län', 'Karlskrona', '16 - Fridlevstad', 'MP', '22'],
#  ['Blekinge län', 'Karlskrona', '16 - Fridlevstad', 'ÖVR', '14'],
#  ['Blekinge län', 'Karlskrona', '16 - Fridlevstad', 'BLANK', '12'],
#  ['Blekinge län', 'Karlskrona', '16 - Fridlevstad', 'FI', '1'],
#  ['Blekinge län', 'Karlskrona', '16 - Fridlevstad', 'OGEJ', '1'],
#  ['Blekinge län', 'Karlskrona', '16 - Fridlevstad', 'OG', '1'],
#  ['Blekinge län', 'Karlskrona', '17 - Hasslö', 'S', '458'],
#  ['Blekinge län', 'Karlskrona', '17 - Hasslö', 'SD', '301'],
#  ['Blekinge län', 'Karlskrona', '17 - Hasslö', 'M', '145'],
#  ['Blekinge län', 'Karlskrona', '17 - Hasslö', 'V', '81'],
#  ['Blekinge län', 'Karlskrona', '17 - Hasslö', 'KD', '70'],
#  ['Blekinge län', 'Karlskrona', '17 - Hasslö', 'C', '57'],
#  ['Blekinge län', 'Karlskrona', '17 - Hasslö', 'L', '35'],
#  ['Blekinge län', 'Karlskrona', '17 - Hasslö', 'MP', '26'],
#  ['Blekinge län', 'Karlskrona', '17 - Hasslö', 'BLANK', '15'],
#  ['Blekinge län', 'Karlskrona', '17 - Hasslö', 'ÖVR', '8'],
#  ['Blekinge län', 'Karlskrona', '17 - Hasslö', 'FI', '3'],
#  ['Blekinge län', 'Karlskrona', '17 - Hasslö', 'OGEJ', '1'],
#  ['Blekinge län', 'Karlskrona', '17 - Hasslö', 'OG', '0'],
#  ['Blekinge län', 'Karlskrona', '18 - Kungsmarken', 'S', '497'],
#  ['Blekinge län', 'Karlskrona', '18 - Kungsmarken', 'SD', '83'],
#  ['Blekinge län', 'Karlskrona', '18 - Kungsmarken', 'V', '69'],
#  ['Blekinge län', 'Karlskrona', '18 - Kungsmarken', 'M', '33'],
#  ['Blekinge län', 'Karlskrona', '18 - Kungsmarken', 'MP', '15'],
#  ['Blekinge län', 'Karlskrona', '18 - Kungsmarken', 'C', '13'],
#  ['Blekinge län', 'Karlskrona', '18 - Kungsmarken', 'BLANK', '10'],
#  ['Blekinge län', 'Karlskrona', '18 - Kungsmarken', 'ÖVR', '9'],
#  ['Blekinge län', 'Karlskrona', '18 - Kungsmarken', 'L', '8'],
#  ['Blekinge län', 'Karlskrona', '18 - Kungsmarken', 'KD', '8'],
#  ['Blekinge län', 'Karlskrona', '18 - Kungsmarken', 'FI', '1'],
#  ['Blekinge län', 'Karlskrona', '18 - Kungsmarken', 'OGEJ', '0'],
#  ['Blekinge län', 'Karlskrona', '18 - Kungsmarken', 'OG', '0'],
#  ['Blekinge län', 'Karlskrona', '19 - Marieberg m.fl.', 'S', '347'],
#  ['Blekinge län', 'Karlskrona', '19 - Marieberg m.fl.', 'SD', '208'],
#  ['Blekinge län', 'Karlskrona', '19 - Marieberg m.fl.', 'M', '112'],
#  ['Blekinge län', 'Karlskrona', '19 - Marieberg m.fl.', 'V', '85'],
#  ['Blekinge län', 'Karlskrona', '19 - Marieberg m.fl.', 'KD', '38'],
#  ['Blekinge län', 'Karlskrona', '19 - Marieberg m.fl.', 'C', '33'],
#  ['Blekinge län', 'Karlskrona', '19 - Marieberg m.fl.', 'L', '30'],
#  ['Blekinge län', 'Karlskrona', '19 - Marieberg m.fl.', 'MP', '29'],
#  ['Blekinge län', 'Karlskrona', '19 - Marieberg m.fl.', 'BLANK', '16'],
#  ['Blekinge län', 'Karlskrona', '19 - Marieberg m.fl.', 'ÖVR', '15'],
#  ['Blekinge län', 'Karlskrona', '19 - Marieberg m.fl.', 'FI', '4'],
#  ['Blekinge län', 'Karlskrona', '19 - Marieberg m.fl.', 'OGEJ', '0'],
#  ['Blekinge län', 'Karlskrona', '19 - Marieberg m.fl.', 'OG', '0'],
#  ['Blekinge län', 'Karlskrona', '1 - Aspö', 'S', '156'],
#  ['Blekinge län', 'Karlskrona', '1 - Aspö', 'SD', '81'],
#  ['Blekinge län', 'Karlskrona', '1 - Aspö', 'M', '57'],
#  ['Blekinge län', 'Karlskrona', '1 - Aspö', 'L', '38'],
#  ['Blekinge län', 'Karlskrona', '1 - Aspö', 'KD', '37'],
#  ['Blekinge län', 'Karlskrona', '1 - Aspö', 'V', '24'],
#  ['Blekinge län', 'Karlskrona', '1 - Aspö', 'MP', '18'],
#  ['Blekinge län', 'Karlskrona', '1 - Aspö', 'C', '14'],
#  ['Blekinge län', 'Karlskrona', '1 - Aspö', 'ÖVR', '6'],
#  ['Blekinge län', 'Karlskrona', '1 - Aspö', 'BLANK', '3'],
#  ['Blekinge län', 'Karlskrona', '1 - Aspö', 'FI', '2'],
#  ['Blekinge län', 'Karlskrona', '1 - Aspö', 'OGEJ', '0'],
#  ['Blekinge län', 'Karlskrona', '1 - Aspö', 'OG', '0'],
#  ['Blekinge län', 'Karlskrona', '20 - Mariedal-Backabo', 'S', '400'],
#  ['Blekinge län', 'Karlskrona', '20 - Mariedal-Backabo', 'SD', '214'],
#  ['Blekinge län', 'Karlskrona', '20 - Mariedal-Backabo', 'M', '177'],
#  ['Blekinge län', 'Karlskrona', '20 - Mariedal-Backabo', 'C', '67'],
#  ['Blekinge län', 'Karlskrona', '20 - Mariedal-Backabo', 'V', '59'],
#  ['Blekinge län', 'Karlskrona', '20 - Mariedal-Backabo', 'KD', '58'],
#  ['Blekinge län', 'Karlskrona', '20 - Mariedal-Backabo', 'L', '51'],
#  ['Blekinge län', 'Karlskrona', '20 - Mariedal-Backabo', 'MP', '29'],
#  ['Blekinge län', 'Karlskrona', '20 - Mariedal-Backabo', 'BLANK', '6'],
#  ['Blekinge län', 'Karlskrona', '20 - Mariedal-Backabo', 'ÖVR', '2'],
#  ['Blekinge län', 'Karlskrona', '20 - Mariedal-Backabo', 'OGEJ', '2'],
#  ['Blekinge län', 'Karlskrona', '20 - Mariedal-Backabo', 'OG', '2'],
#  ['Blekinge län', 'Karlskrona', '20 - Mariedal-Backabo', 'FI', '0'],
#  ['Blekinge län', 'Karlskrona', '21 - Nättraby S', 'M', '352'],
#  ['Blekinge län', 'Karlskrona', '21 - Nättraby S', 'S', '351'],
#  ['Blekinge län', 'Karlskrona', '21 - Nättraby S', 'SD', '236'],
#  ['Blekinge län', 'Karlskrona', '21 - Nättraby S', 'C', '119'],
#  ['Blekinge län', 'Karlskrona', '21 - Nättraby S', 'KD', '94'],
#  ['Blekinge län', 'Karlskrona', '21 - Nättraby S', 'L', '92'],
#  ['Blekinge län', 'Karlskrona', '21 - Nättraby S', 'MP', '43'],
#  ['Blekinge län', 'Karlskrona', '21 - Nättraby S', 'V', '41'],
#  ['Blekinge län', 'Karlskrona', '21 - Nättraby S', 'BLANK', '13'],
#  ['Blekinge län', 'Karlskrona', '21 - Nättraby S', 'ÖVR', '7'],
#  ['Blekinge län', 'Karlskrona', '21 - Nättraby S', 'FI', '2'],
#  ['Blekinge län', 'Karlskrona', '21 - Nättraby S', 'OG', '1'],
#  ['Blekinge län', 'Karlskrona', '21 - Nättraby S', 'OGEJ', '0'],
#  ['Blekinge län', 'Karlskrona', '22 - Nättraby V', 'S', '337'],
#  ['Blekinge län', 'Karlskrona', '22 - Nättraby V', 'SD', '206'],
#  ['Blekinge län', 'Karlskrona', '22 - Nättraby V', 'M', '172'],
#  ['Blekinge län', 'Karlskrona', '22 - Nättraby V', 'KD', '54'],
#  ['Blekinge län', 'Karlskrona', '22 - Nättraby V', 'C', '53'],
#  ['Blekinge län', 'Karlskrona', '22 - Nättraby V', 'V', '50'],
#  ['Blekinge län', 'Karlskrona', '22 - Nättraby V', 'MP', '46'],
#  ['Blekinge län', 'Karlskrona', '22 - Nättraby V', 'L', '33'],
#  ['Blekinge län', 'Karlskrona', '22 - Nättraby V', 'BLANK', '18'],
#  ['Blekinge län', 'Karlskrona', '22 - Nättraby V', 'ÖVR', '5'],
#  ['Blekinge län', 'Karlskrona', '22 - Nättraby V', 'FI', '3'],
#  ['Blekinge län', 'Karlskrona', '22 - Nättraby V', 'OG', '1'],
#  ['Blekinge län', 'Karlskrona', '22 - Nättraby V', 'OGEJ', '0'],
#  ['Blekinge län', 'Karlskrona', '23 - Nättraby Ö', 'S', '311'],
#  ['Blekinge län', 'Karlskrona', '23 - Nättraby Ö', 'M', '291'],
#  ['Blekinge län', 'Karlskrona', '23 - Nättraby Ö', 'SD', '162'],
#  ['Blekinge län', 'Karlskrona', '23 - Nättraby Ö', 'C', '98'],
#  ['Blekinge län', 'Karlskrona', '23 - Nättraby Ö', 'KD', '76'],
#  ['Blekinge län', 'Karlskrona', '23 - Nättraby Ö', 'L', '64'],
#  ['Blekinge län', 'Karlskrona', '23 - Nättraby Ö', 'MP', '50'],
#  ['Blekinge län', 'Karlskrona', '23 - Nättraby Ö', 'V', '42'],
#  ['Blekinge län', 'Karlskrona', '23 - Nättraby Ö', 'BLANK', '10'],
#  ['Blekinge län', 'Karlskrona', '23 - Nättraby Ö', 'ÖVR', '9'],
#  ['Blekinge län', 'Karlskrona', '23 - Nättraby Ö', 'FI', '3'],
#  ['Blekinge län', 'Karlskrona', '23 - Nättraby Ö', 'OGEJ', '2'],
#  ['Blekinge län', 'Karlskrona', '23 - Nättraby Ö', 'OG', '1'],
#  ['Blekinge län', 'Karlskrona', '24 - Rödeby N', 'S', '507'],
#  ['Blekinge län', 'Karlskrona', '24 - Rödeby N', 'SD', '346'],
#  ['Blekinge län', 'Karlskrona', '24 - Rödeby N', 'M', '251'],
#  ['Blekinge län', 'Karlskrona', '24 - Rödeby N', 'C', '91'],
#  ['Blekinge län', 'Karlskrona', '24 - Rödeby N', 'L', '73'],
#  ['Blekinge län', 'Karlskrona', '24 - Rödeby N', 'KD', '65'],
#  ['Blekinge län', 'Karlskrona', '24 - Rödeby N', 'V', '46'],
#  ['Blekinge län', 'Karlskrona', '24 - Rödeby N', 'MP', '22'],
#  ['Blekinge län', 'Karlskrona', '24 - Rödeby N', 'ÖVR', '15'],
#  ['Blekinge län', 'Karlskrona', '24 - Rödeby N', 'BLANK', '14'],
#  ['Blekinge län', 'Karlskrona', '24 - Rödeby N', 'FI', '2'],
#  ['Blekinge län', 'Karlskrona', '24 - Rödeby N', 'OGEJ', '0'],
#  ['Blekinge län', 'Karlskrona', '24 - Rödeby N', 'OG', '0'],
#  ['Blekinge län', 'Karlskrona', '25 - Rödeby S', 'S', '432'],
#  ['Blekinge län', 'Karlskrona', '25 - Rödeby S', 'SD', '287'],
#  ['Blekinge län', 'Karlskrona', '25 - Rödeby S', 'M', '200'],
#  ['Blekinge län', 'Karlskrona', '25 - Rödeby S', 'KD', '68'],
#  ['Blekinge län', 'Karlskrona', '25 - Rödeby S', 'C', '66'],
#  ['Blekinge län', 'Karlskrona', '25 - Rödeby S', 'L', '65'],
#  ['Blekinge län', 'Karlskrona', '25 - Rödeby S', 'V', '36'],
#  ['Blekinge län', 'Karlskrona', '25 - Rödeby S', 'MP', '26'],
#  ['Blekinge län', 'Karlskrona', '25 - Rödeby S', 'BLANK', '13'],
#  ['Blekinge län', 'Karlskrona', '25 - Rödeby S', 'ÖVR', '7'],
#  ['Blekinge län', 'Karlskrona', '25 - Rödeby S', 'FI', '4'],
#  ['Blekinge län', 'Karlskrona', '25 - Rödeby S', 'OGEJ', '0'],
#  ['Blekinge län', 'Karlskrona', '25 - Rödeby S', 'OG', '0'],
#  ['Blekinge län', 'Karlskrona', '26 - Sillhövda', 'SD', '228'],
#  ['Blekinge län', 'Karlskrona', '26 - Sillhövda', 'S', '176'],
#  ['Blekinge län', 'Karlskrona', '26 - Sillhövda', 'C', '87'],
#  ['Blekinge län', 'Karlskrona', '26 - Sillhövda', 'M', '84'],
#  ['Blekinge län', 'Karlskrona', '26 - Sillhövda', 'KD', '58'],
#  ['Blekinge län', 'Karlskrona', '26 - Sillhövda', 'V', '53'],
#  ['Blekinge län', 'Karlskrona', '26 - Sillhövda', 'MP', '17'],
#  ['Blekinge län', 'Karlskrona', '26 - Sillhövda', 'L', '14'],
#  ['Blekinge län', 'Karlskrona', '26 - Sillhövda', 'BLANK', '8'],
#  ['Blekinge län', 'Karlskrona', '26 - Sillhövda', 'ÖVR', '6'],
#  ['Blekinge län', 'Karlskrona', '26 - Sillhövda', 'FI', '1'],
#  ['Blekinge län', 'Karlskrona', '26 - Sillhövda', 'OGEJ', '0'],
#  ['Blekinge län', 'Karlskrona', '26 - Sillhövda', 'OG', '0'],
#  ['Blekinge län', 'Karlskrona', '27 - Strömsberg', 'SD', '229'],
#  ['Blekinge län', 'Karlskrona', '27 - Strömsberg', 'S', '228'],
#  ['Blekinge län', 'Karlskrona', '27 - Strömsberg', 'M', '92'],
#  ['Blekinge län', 'Karlskrona', '27 - Strömsberg', 'C', '82'],
#  ['Blekinge län', 'Karlskrona', '27 - Strömsberg', 'V', '30'],
#  ['Blekinge län', 'Karlskrona', '27 - Strömsberg', 'KD', '27'],
#  ['Blekinge län', 'Karlskrona', '27 - Strömsberg', 'L', '17'],
#  ['Blekinge län', 'Karlskrona', '27 - Strömsberg', 'MP', '17'],
#  ['Blekinge län', 'Karlskrona', '27 - Strömsberg', 'BLANK', '13'],
#  ['Blekinge län', 'Karlskrona', '27 - Strömsberg', 'ÖVR', '5'],
#  ['Blekinge län', 'Karlskrona', '27 - Strömsberg', 'FI', '1'],
#  ['Blekinge län', 'Karlskrona', '27 - Strömsberg', 'OGEJ', '0'],
#  ['Blekinge län', 'Karlskrona', '27 - Strömsberg', 'OG', '0'],
#  ['Blekinge län', 'Karlskrona', '28 - Tving', 'SD', '441'],
#  ['Blekinge län', 'Karlskrona', '28 - Tving', 'S', '300'],
#  ['Blekinge län', 'Karlskrona', '28 - Tving', 'M', '155'],
#  ['Blekinge län', 'Karlskrona', '28 - Tving', 'C', '136'],
#  ['Blekinge län', 'Karlskrona', '28 - Tving', 'KD', '68'],
#  ['Blekinge län', 'Karlskrona', '28 - Tving', 'V', '57'],
#  ['Blekinge län', 'Karlskrona', '28 - Tving', 'L', '34'],
#  ['Blekinge län', 'Karlskrona', '28 - Tving', 'ÖVR', '12'],
#  ['Blekinge län', 'Karlskrona', '28 - Tving', 'MP', '10'],
#  ['Blekinge län', 'Karlskrona', '28 - Tving', 'BLANK', '9'],
#  ['Blekinge län', 'Karlskrona', '28 - Tving', 'FI', '5'],
#  ['Blekinge län', 'Karlskrona', '28 - Tving', 'OGEJ', '1'],
#  ['Blekinge län', 'Karlskrona', '28 - Tving', 'OG', '1'],
#  ['Blekinge län', 'Karlskrona', '29 - Uppsamlingsdistrikt', 'SD', '49'],
#  ['Blekinge län', 'Karlskrona', '29 - Uppsamlingsdistrikt', 'S', '47'],
#  ['Blekinge län', 'Karlskrona', '29 - Uppsamlingsdistrikt', 'M', '41'],
#  ['Blekinge län', 'Karlskrona', '29 - Uppsamlingsdistrikt', 'C', '32'],
#  ['Blekinge län', 'Karlskrona', '29 - Uppsamlingsdistrikt', 'V', '17'],
#  ['Blekinge län', 'Karlskrona', '29 - Uppsamlingsdistrikt', 'MP', '16'],
#  ['Blekinge län', 'Karlskrona', '29 - Uppsamlingsdistrikt', 'KD', '10'],
#  ['Blekinge län', 'Karlskrona', '29 - Uppsamlingsdistrikt', 'L', '7'],
#  ['Blekinge län', 'Karlskrona', '29 - Uppsamlingsdistrikt', 'FI', '3'],
#  ['Blekinge län', 'Karlskrona', '29 - Uppsamlingsdistrikt', 'ÖVR', '2'],
#  ['Blekinge län', 'Karlskrona', '29 - Uppsamlingsdistrikt', 'BLANK', '2'],
#  ['Blekinge län', 'Karlskrona', '29 - Uppsamlingsdistrikt', 'OG', '1'],
#  ['Blekinge län', 'Karlskrona', '29 - Uppsamlingsdistrikt', 'OGEJ', '0'],
#  ['Blekinge län', 'Karlskrona', '2 - Bergåsa m.fl.', 'S', '209'],
#  ['Blekinge län', 'Karlskrona', '2 - Bergåsa m.fl.', 'M', '208'],
#  ['Blekinge län', 'Karlskrona', '2 - Bergåsa m.fl.', 'SD', '116'],
#  ['Blekinge län', 'Karlskrona', '2 - Bergåsa m.fl.', 'C', '89'],
#  ['Blekinge län', 'Karlskrona', '2 - Bergåsa m.fl.', 'L', '89'],
#  ['Blekinge län', 'Karlskrona', '2 - Bergåsa m.fl.', 'V', '55'],
#  ['Blekinge län', 'Karlskrona', '2 - Bergåsa m.fl.', 'MP', '55'],
#  ['Blekinge län', 'Karlskrona', '2 - Bergåsa m.fl.', 'KD', '44'],
#  ['Blekinge län', 'Karlskrona', '2 - Bergåsa m.fl.', 'ÖVR', '16'],
#  ['Blekinge län', 'Karlskrona', '2 - Bergåsa m.fl.', 'FI', '4'],
#  ['Blekinge län', 'Karlskrona', '2 - Bergåsa m.fl.', 'BLANK', '4'],
#  ['Blekinge län', 'Karlskrona', '2 - Bergåsa m.fl.', 'OGEJ', '1'],
#  ['Blekinge län', 'Karlskrona', '2 - Bergåsa m.fl.', 'OG', '1'],
#  ['Blekinge län', 'Karlskrona', '31 - Jämjö N', 'S', '488'],
#  ['Blekinge län', 'Karlskrona', '31 - Jämjö N', 'SD', '377'],
#  ['Blekinge län', 'Karlskrona', '31 - Jämjö N', 'M', '183'],
#  ['Blekinge län', 'Karlskrona', '31 - Jämjö N', 'KD', '111'],
#  ['Blekinge län', 'Karlskrona', '31 - Jämjö N', 'C', '101'],
#  ['Blekinge län', 'Karlskrona', '31 - Jämjö N', 'V', '53'],
#  ['Blekinge län', 'Karlskrona', '31 - Jämjö N', 'L', '38'],
#  ['Blekinge län', 'Karlskrona', '31 - Jämjö N', 'MP', '27'],
#  ['Blekinge län', 'Karlskrona', '31 - Jämjö N', 'ÖVR', '10'],
#  ['Blekinge län', 'Karlskrona', '31 - Jämjö N', 'BLANK', '9'],
#  ['Blekinge län', 'Karlskrona', '31 - Jämjö N', 'FI', '2'],
#  ['Blekinge län', 'Karlskrona', '31 - Jämjö N', 'OG', '2'],
#  ['Blekinge län', 'Karlskrona', '31 - Jämjö N', 'OGEJ', '0'],
#  ['Blekinge län', 'Karlskrona', '32 - Jämjö S', 'S', '394'],
#  ['Blekinge län', 'Karlskrona', '32 - Jämjö S', 'SD', '250'],
#  ['Blekinge län', 'Karlskrona', '32 - Jämjö S', 'M', '156'],
#  ['Blekinge län', 'Karlskrona', '32 - Jämjö S', 'KD', '89'],
#  ['Blekinge län', 'Karlskrona', '32 - Jämjö S', 'C', '71'],
#  ['Blekinge län', 'Karlskrona', '32 - Jämjö S', 'L', '53'],
#  ['Blekinge län', 'Karlskrona', '32 - Jämjö S', 'V', '50'],
#  ['Blekinge län', 'Karlskrona', '32 - Jämjö S', 'MP', '22'],
#  ['Blekinge län', 'Karlskrona', '32 - Jämjö S', 'BLANK', '8'],
#  ['Blekinge län', 'Karlskrona', '32 - Jämjö S', 'ÖVR', '7'],
#  ['Blekinge län', 'Karlskrona', '32 - Jämjö S', 'FI', '2'],
#  ['Blekinge län', 'Karlskrona', '32 - Jämjö S', 'OGEJ', '0'],
#  ['Blekinge län', 'Karlskrona', '32 - Jämjö S', 'OG', '0'],
#  ['Blekinge län', 'Karlskrona', '33 - Kristianopel', 'SD', '341'],
#  ['Blekinge län', 'Karlskrona', '33 - Kristianopel', 'S', '249'],
#  ['Blekinge län', 'Karlskrona', '33 - Kristianopel', 'M', '131'],
#  ['Blekinge län', 'Karlskrona', '33 - Kristianopel', 'C', '101'],
#  ['Blekinge län', 'Karlskrona', '33 - Kristianopel', 'KD', '75'],
#  ['Blekinge län', 'Karlskrona', '33 - Kristianopel', 'V', '54'],
#  ['Blekinge län', 'Karlskrona', '33 - Kristianopel', 'L', '23'],
#  ['Blekinge län', 'Karlskrona', '33 - Kristianopel', 'MP', '16'],
#  ['Blekinge län', 'Karlskrona', '33 - Kristianopel', 'ÖVR', '10'],
#  ['Blekinge län', 'Karlskrona', '33 - Kristianopel', 'BLANK', '10'],
#  ['Blekinge län', 'Karlskrona', '33 - Kristianopel', 'FI', '1'],
#  ['Blekinge län', 'Karlskrona', '33 - Kristianopel', 'OGEJ', '0'],
#  ['Blekinge län', 'Karlskrona', '33 - Kristianopel', 'OG', '0'],
#  ['Blekinge län', 'Karlskrona', '34 - Kronotorp m.fl.', 'S', '347'],
#  ['Blekinge län', 'Karlskrona', '34 - Kronotorp m.fl.', 'SD', '196'],
#  ['Blekinge län', 'Karlskrona', '34 - Kronotorp m.fl.', 'M', '133'],
#  ['Blekinge län', 'Karlskrona', '34 - Kronotorp m.fl.', 'KD', '60'],
#  ['Blekinge län', 'Karlskrona', '34 - Kronotorp m.fl.', 'C', '50'],
#  ['Blekinge län', 'Karlskrona', '34 - Kronotorp m.fl.', 'V', '46'],
#  ['Blekinge län', 'Karlskrona', '34 - Kronotorp m.fl.', 'L', '33'],
#  ['Blekinge län', 'Karlskrona', '34 - Kronotorp m.fl.', 'MP', '33'],
#  ['Blekinge län', 'Karlskrona', '34 - Kronotorp m.fl.', 'ÖVR', '11'],
#  ['Blekinge län', 'Karlskrona', '34 - Kronotorp m.fl.', 'BLANK', '10'],
#  ['Blekinge län', 'Karlskrona', '34 - Kronotorp m.fl.', 'FI', '2'],
#  ['Blekinge län', 'Karlskrona', '34 - Kronotorp m.fl.', 'OG', '2'],
#  ['Blekinge län', 'Karlskrona', '34 - Kronotorp m.fl.', 'OGEJ', '0'],
#  ['Blekinge län', 'Karlskrona', '35 - Kättilsmåla', 'SD', '238'],
#  ['Blekinge län', 'Karlskrona', '35 - Kättilsmåla', 'S', '203'],
#  ['Blekinge län', 'Karlskrona', '35 - Kättilsmåla', 'M', '96'],
#  ['Blekinge län', 'Karlskrona', '35 - Kättilsmåla', 'C', '96'],
#  ['Blekinge län', 'Karlskrona', '35 - Kättilsmåla', 'KD', '43'],
#  ['Blekinge län', 'Karlskrona', '35 - Kättilsmåla', 'V', '31'],
#  ['Blekinge län', 'Karlskrona', '35 - Kättilsmåla', 'MP', '19'],
#  ['Blekinge län', 'Karlskrona', '35 - Kättilsmåla', 'ÖVR', '6'],
#  ['Blekinge län', 'Karlskrona', '35 - Kättilsmåla', 'L', '5'],
#  ['Blekinge län', 'Karlskrona', '35 - Kättilsmåla', 'BLANK', '5'],
#  ['Blekinge län', 'Karlskrona', '35 - Kättilsmåla', 'FI', '0'],
#  ['Blekinge län', 'Karlskrona', '35 - Kättilsmåla', 'OGEJ', '0'],
#  ['Blekinge län', 'Karlskrona', '35 - Kättilsmåla', 'OG', '0'],
#  ['Blekinge län', 'Karlskrona', '36 - Lyckeby V', 'S', '458'],
#  ['Blekinge län', 'Karlskrona', '36 - Lyckeby V', 'SD', '233'],
#  ['Blekinge län', 'Karlskrona', '36 - Lyckeby V', 'M', '167'],
#  ['Blekinge län', 'Karlskrona', '36 - Lyckeby V', 'KD', '90'],
#  ['Blekinge län', 'Karlskrona', '36 - Lyckeby V', 'L', '59'],
#  ['Blekinge län', 'Karlskrona', '36 - Lyckeby V', 'V', '59'],
#  ['Blekinge län', 'Karlskrona', '36 - Lyckeby V', 'C', '46'],
#  ['Blekinge län', 'Karlskrona', '36 - Lyckeby V', 'MP', '29'],
#  ['Blekinge län', 'Karlskrona', '36 - Lyckeby V', 'ÖVR', '8'],
#  ['Blekinge län', 'Karlskrona', '36 - Lyckeby V', 'BLANK', '8'],
#  ['Blekinge län', 'Karlskrona', '36 - Lyckeby V', 'FI', '0'],
#  ['Blekinge län', 'Karlskrona', '36 - Lyckeby V', 'OGEJ', '0'],
#  ['Blekinge län', 'Karlskrona', '36 - Lyckeby V', 'OG', '0'],
#  ['Blekinge län', 'Karlskrona', '37 - Lyckeby Ö', 'S', '449'],
#  ['Blekinge län', 'Karlskrona', '37 - Lyckeby Ö', 'M', '315'],
#  ['Blekinge län', 'Karlskrona', '37 - Lyckeby Ö', 'SD', '315'],
#  ['Blekinge län', 'Karlskrona', '37 - Lyckeby Ö', 'KD', '137'],
#  ['Blekinge län', 'Karlskrona', '37 - Lyckeby Ö', 'C', '129'],
#  ['Blekinge län', 'Karlskrona', '37 - Lyckeby Ö', 'L', '89'],
#  ['Blekinge län', 'Karlskrona', '37 - Lyckeby Ö', 'V', '81'],
#  ['Blekinge län', 'Karlskrona', '37 - Lyckeby Ö', 'MP', '63'],
#  ['Blekinge län', 'Karlskrona', '37 - Lyckeby Ö', 'ÖVR', '12'],
#  ['Blekinge län', 'Karlskrona', '37 - Lyckeby Ö', 'BLANK', '12'],
#  ['Blekinge län', 'Karlskrona', '37 - Lyckeby Ö', 'FI', '6'],
#  ['Blekinge län', 'Karlskrona', '37 - Lyckeby Ö', 'OGEJ', '1'],
#  ['Blekinge län', 'Karlskrona', '37 - Lyckeby Ö', 'OG', '0'],
#  ['Blekinge län', 'Karlskrona', '38 - Ramdala', 'S', '492'],
#  ['Blekinge län', 'Karlskrona', '38 - Ramdala', 'M', '377'],
#  ['Blekinge län', 'Karlskrona', '38 - Ramdala', 'SD', '352'],
#  ['Blekinge län', 'Karlskrona', '38 - Ramdala', 'C', '153'],
#  ['Blekinge län', 'Karlskrona', '38 - Ramdala', 'KD', '148'],
#  ['Blekinge län', 'Karlskrona', '38 - Ramdala', 'L', '75'],
#  ['Blekinge län', 'Karlskrona', '38 - Ramdala', 'V', '61'],
#  ['Blekinge län', 'Karlskrona', '38 - Ramdala', 'MP', '53'],
#  ['Blekinge län', 'Karlskrona', '38 - Ramdala', 'ÖVR', '10'],
#  ['Blekinge län', 'Karlskrona', '38 - Ramdala', 'BLANK', '10'],
#  ['Blekinge län', 'Karlskrona', '38 - Ramdala', 'FI', '1'],
#  ['Blekinge län', 'Karlskrona', '38 - Ramdala', 'OGEJ', '0'],
#  ['Blekinge län', 'Karlskrona', '38 - Ramdala', 'OG', '0'],
#  ['Blekinge län', 'Karlskrona', '39 - Spandelstorp m.fl.', 'S', '461'],
#  ['Blekinge län', 'Karlskrona', '39 - Spandelstorp m.fl.', 'SD', '305'],
#  ['Blekinge län', 'Karlskrona', '39 - Spandelstorp m.fl.', 'M', '283'],
#  ['Blekinge län', 'Karlskrona', '39 - Spandelstorp m.fl.', 'KD', '85'],
#  ['Blekinge län', 'Karlskrona', '39 - Spandelstorp m.fl.', 'V', '81'],
#  ['Blekinge län', 'Karlskrona', '39 - Spandelstorp m.fl.', 'C', '75'],
#  ['Blekinge län', 'Karlskrona', '39 - Spandelstorp m.fl.', 'L', '65'],
#  ['Blekinge län', 'Karlskrona', '39 - Spandelstorp m.fl.', 'MP', '51'],
#  ['Blekinge län', 'Karlskrona', '39 - Spandelstorp m.fl.', 'BLANK', '16'],
#  ['Blekinge län', 'Karlskrona', '39 - Spandelstorp m.fl.', 'ÖVR', '15'],
#  ['Blekinge län', 'Karlskrona', '39 - Spandelstorp m.fl.', 'OG', '2'],
#  ['Blekinge län', 'Karlskrona', '39 - Spandelstorp m.fl.', 'FI', '1'],
#  ['Blekinge län', 'Karlskrona', '39 - Spandelstorp m.fl.', 'OGEJ', '0'],
#  ['Blekinge län', 'Karlskrona', '3 - Galgamarken', 'S', '288'],
#  ['Blekinge län', 'Karlskrona', '3 - Galgamarken', 'SD', '210'],
#  ['Blekinge län', 'Karlskrona', '3 - Galgamarken', 'M', '112'],
#  ['Blekinge län', 'Karlskrona', '3 - Galgamarken', 'V', '86'],
#  ['Blekinge län', 'Karlskrona', '3 - Galgamarken', 'MP', '51'],
#  ['Blekinge län', 'Karlskrona', '3 - Galgamarken', 'C', '50'],
#  ['Blekinge län', 'Karlskrona', '3 - Galgamarken', 'L', '50'],
#  ['Blekinge län', 'Karlskrona', '3 - Galgamarken', 'KD', '27'],
#  ['Blekinge län', 'Karlskrona', '3 - Galgamarken', 'ÖVR', '27'],
#  ['Blekinge län', 'Karlskrona', '3 - Galgamarken', 'BLANK', '11'],
#  ['Blekinge län', 'Karlskrona', '3 - Galgamarken', 'FI', '6'],
#  ['Blekinge län', 'Karlskrona', '3 - Galgamarken', 'OGEJ', '1'],
#  ['Blekinge län', 'Karlskrona', '3 - Galgamarken', 'OG', '1'],
#  ['Blekinge län', 'Karlskrona', '40 - Sturkö', 'S', '419'],
#  ['Blekinge län', 'Karlskrona', '40 - Sturkö', 'SD', '333'],
#  ['Blekinge län', 'Karlskrona', '40 - Sturkö', 'M', '182'],
#  ['Blekinge län', 'Karlskrona', '40 - Sturkö', 'KD', '73'],
#  ['Blekinge län', 'Karlskrona', '40 - Sturkö', 'C', '69'],
#  ['Blekinge län', 'Karlskrona', '40 - Sturkö', 'V', '68'],
#  ['Blekinge län', 'Karlskrona', '40 - Sturkö', 'L', '56'],
#  ['Blekinge län', 'Karlskrona', '40 - Sturkö', 'MP', '27'],
#  ['Blekinge län', 'Karlskrona', '40 - Sturkö', 'ÖVR', '11'],
#  ['Blekinge län', 'Karlskrona', '40 - Sturkö', 'BLANK', '6'],
#  ['Blekinge län', 'Karlskrona', '40 - Sturkö', 'FI', '3'],
#  ['Blekinge län', 'Karlskrona', '40 - Sturkö', 'OGEJ', '0'],
#  ['Blekinge län', 'Karlskrona', '40 - Sturkö', 'OG', '0'],
#  ['Blekinge län', 'Karlskrona', '41 - Torhamn', 'SD', '331'],
#  ['Blekinge län', 'Karlskrona', '41 - Torhamn', 'S', '305'],
#  ['Blekinge län', 'Karlskrona', '41 - Torhamn', 'M', '149'],
#  ['Blekinge län', 'Karlskrona', '41 - Torhamn', 'C', '107'],
#  ['Blekinge län', 'Karlskrona', '41 - Torhamn', 'KD', '88'],
#  ['Blekinge län', 'Karlskrona', '41 - Torhamn', 'V', '59'],
#  ['Blekinge län', 'Karlskrona', '41 - Torhamn', 'L', '31'],
#  ['Blekinge län', 'Karlskrona', '41 - Torhamn', 'MP', '31'],
#  ['Blekinge län', 'Karlskrona', '41 - Torhamn', 'ÖVR', '12'],
#  ['Blekinge län', 'Karlskrona', '41 - Torhamn', 'BLANK', '4'],
#  ['Blekinge län', 'Karlskrona', '41 - Torhamn', 'FI', '3'],
#  ['Blekinge län', 'Karlskrona', '41 - Torhamn', 'OG', '2'],
#  ['Blekinge län', 'Karlskrona', '41 - Torhamn', 'OGEJ', '0'],
#  ['Blekinge län', 'Karlskrona', '42 - Torskors-Hässlegården', 'S', '471'],
#  ['Blekinge län', 'Karlskrona', '42 - Torskors-Hässlegården', 'M', '347'],
#  ['Blekinge län', 'Karlskrona', '42 - Torskors-Hässlegården', 'SD', '244'],
#  ['Blekinge län', 'Karlskrona', '42 - Torskors-Hässlegården', 'C', '110'],
#  ['Blekinge län', 'Karlskrona', '42 - Torskors-Hässlegården', 'L', '92'],
#  ['Blekinge län', 'Karlskrona', '42 - Torskors-Hässlegården', 'KD', '87'],
#  ['Blekinge län', 'Karlskrona', '42 - Torskors-Hässlegården', 'MP', '67'],
#  ['Blekinge län', 'Karlskrona', '42 - Torskors-Hässlegården', 'V', '54'],
#  ['Blekinge län', 'Karlskrona', '42 - Torskors-Hässlegården', 'ÖVR', '12'],
#  ['Blekinge län', 'Karlskrona', '42 - Torskors-Hässlegården', 'BLANK', '12'],
#  ['Blekinge län', 'Karlskrona', '42 - Torskors-Hässlegården', 'FI', '2'],
#  ['Blekinge län', 'Karlskrona', '42 - Torskors-Hässlegården', 'OGEJ', '0'],
#  ['Blekinge län', 'Karlskrona', '42 - Torskors-Hässlegården', 'OG', '0'],
#  ['Blekinge län', 'Karlskrona', '43 - Verkö m.fl.', 'M', '308'],
#  ['Blekinge län', 'Karlskrona', '43 - Verkö m.fl.', 'S', '255'],
#  ['Blekinge län', 'Karlskrona', '43 - Verkö m.fl.', 'SD', '158'],
#  ['Blekinge län', 'Karlskrona', '43 - Verkö m.fl.', 'KD', '80'],
#  ['Blekinge län', 'Karlskrona', '43 - Verkö m.fl.', 'C', '77'],
#  ['Blekinge län', 'Karlskrona', '43 - Verkö m.fl.', 'L', '77'],
#  ['Blekinge län', 'Karlskrona', '43 - Verkö m.fl.', 'V', '42'],
#  ['Blekinge län', 'Karlskrona', '43 - Verkö m.fl.', 'MP', '38'],
#  ['Blekinge län', 'Karlskrona', '43 - Verkö m.fl.', 'ÖVR', '5'],
#  ['Blekinge län', 'Karlskrona', '43 - Verkö m.fl.', 'BLANK', '5'],
#  ['Blekinge län', 'Karlskrona', '43 - Verkö m.fl.', 'OG', '1'],
#  ['Blekinge län', 'Karlskrona', '43 - Verkö m.fl.', 'FI', '0'],
#  ['Blekinge län', 'Karlskrona', '43 - Verkö m.fl.', 'OGEJ', '0'],
#  ['Blekinge län', 'Karlskrona', '44 - Uppsamlingsdistrikt', 'M', '51'],
#  ['Blekinge län', 'Karlskrona', '44 - Uppsamlingsdistrikt', 'S', '41'],
#  ['Blekinge län', 'Karlskrona', '44 - Uppsamlingsdistrikt', 'SD', '32'],
#  ['Blekinge län', 'Karlskrona', '44 - Uppsamlingsdistrikt', 'C', '19'],
#  ['Blekinge län', 'Karlskrona', '44 - Uppsamlingsdistrikt', 'L', '18'],
#  ['Blekinge län', 'Karlskrona', '44 - Uppsamlingsdistrikt', 'MP', '14'],
#  ['Blekinge län', 'Karlskrona', '44 - Uppsamlingsdistrikt', 'KD', '13'],
#  ['Blekinge län', 'Karlskrona', '44 - Uppsamlingsdistrikt', 'V', '13'],
#  ['Blekinge län', 'Karlskrona', '44 - Uppsamlingsdistrikt', 'ÖVR', '8'],
#  ['Blekinge län', 'Karlskrona', '44 - Uppsamlingsdistrikt', 'FI', '2'],
#  ['Blekinge län', 'Karlskrona', '44 - Uppsamlingsdistrikt', 'BLANK', '2'],
#  ['Blekinge län', 'Karlskrona', '44 - Uppsamlingsdistrikt', 'OGEJ', '0'],
#  ['Blekinge län', 'Karlskrona', '44 - Uppsamlingsdistrikt', 'OG', '0'],
#  ['Blekinge län', 'Karlskrona', '4 - Hogland m.fl.', 'S', '308'],
#  ['Blekinge län', 'Karlskrona', '4 - Hogland m.fl.', 'M', '192'],
#  ['Blekinge län', 'Karlskrona', '4 - Hogland m.fl.', 'SD', '166'],
#  ['Blekinge län', 'Karlskrona', '4 - Hogland m.fl.', 'V', '76'],
#  ['Blekinge län', 'Karlskrona', '4 - Hogland m.fl.', 'C', '53'],
#  ['Blekinge län', 'Karlskrona', '4 - Hogland m.fl.', 'L', '52'],
#  ['Blekinge län', 'Karlskrona', '4 - Hogland m.fl.', 'KD', '52'],
#  ['Blekinge län', 'Karlskrona', '4 - Hogland m.fl.', 'MP', '32'],
#  ['Blekinge län', 'Karlskrona', '4 - Hogland m.fl.', 'BLANK', '12'],
#  ['Blekinge län', 'Karlskrona', '4 - Hogland m.fl.', 'ÖVR', '8'],
#  ['Blekinge län', 'Karlskrona', '4 - Hogland m.fl.', 'FI', '7'],
#  ['Blekinge län', 'Karlskrona', '4 - Hogland m.fl.', 'OGEJ', '0'],
#  ['Blekinge län', 'Karlskrona', '4 - Hogland m.fl.', 'OG', '0'],
#  ['Blekinge län', 'Karlskrona', '5 - Hästö', 'M', '303'],
#  ['Blekinge län', 'Karlskrona', '5 - Hästö', 'S', '236'],
#  ['Blekinge län', 'Karlskrona', '5 - Hästö', 'SD', '161'],
#  ['Blekinge län', 'Karlskrona', '5 - Hästö', 'L', '89'],
#  ['Blekinge län', 'Karlskrona', '5 - Hästö', 'C', '84'],
#  ['Blekinge län', 'Karlskrona', '5 - Hästö', 'KD', '55'],
#  ['Blekinge län', 'Karlskrona', '5 - Hästö', 'V', '54'],
#  ['Blekinge län', 'Karlskrona', '5 - Hästö', 'MP', '52'],
#  ['Blekinge län', 'Karlskrona', '5 - Hästö', 'BLANK', '9'],
#  ['Blekinge län', 'Karlskrona', '5 - Hästö', 'ÖVR', '7'],
#  ['Blekinge län', 'Karlskrona', '5 - Hästö', 'FI', '6'],
#  ['Blekinge län', 'Karlskrona', '5 - Hästö', 'OG', '1'],
#  ['Blekinge län', 'Karlskrona', '5 - Hästö', 'OGEJ', '0'],
#  ['Blekinge län', 'Karlskrona', '6 - Långö-Gräsvik', 'S', '277'],
#  ['Blekinge län', 'Karlskrona', '6 - Långö-Gräsvik', 'M', '238'],
#  ['Blekinge län', 'Karlskrona', '6 - Långö-Gräsvik', 'SD', '154'],
#  ['Blekinge län', 'Karlskrona', '6 - Långö-Gräsvik', 'L', '100'],
# ...
#  ['Blekinge län', 'Karlskrona', '6 - Långö-Gräsvik', 'OG', '1'],
#  ['Blekinge län', 'Karlskrona', '6 - Långö-Gräsvik', 'OGEJ', '0'],
#  ['Blekinge län', 'Karlskrona', '7 - Möllebacken m.fl.', 'S', '343'],
#  ['Blekinge län', 'Karlskrona', '7 - Möllebacken m.fl.', 'M', '275'],
#  ['Blekinge län', 'Karlskrona', '7 - Möllebacken m.fl.', 'SD', '238'],
#  ['Blekinge län', 'Karlskrona', '7 - Möllebacken m.fl.', 'C', '104'],
#  ['Blekinge län', 'Karlskrona', '7 - Möllebacken m.fl.', 'L', '85'],
#  ['Blekinge län', 'Karlskrona', '7 - Möllebacken m.fl.', 'V', '81'],
#  ['Blekinge län', 'Karlskrona', '7 - Möllebacken m.fl.', 'KD', '78'],
#  ['Blekinge län', 'Karlskrona', '7 - Möllebacken m.fl.', 'MP', '56'],
#  ['Blekinge län', 'Karlskrona', '7 - Möllebacken m.fl.', 'ÖVR', '13'],
#  ['Blekinge län', 'Karlskrona', '7 - Möllebacken m.fl.', 'BLANK', '12'],
#  ['Blekinge län', 'Karlskrona', '7 - Möllebacken m.fl.', 'FI', '2'],
#  ['Blekinge län', 'Karlskrona', '7 - Möllebacken m.fl.', 'OGEJ', '0'],
#  ['Blekinge län', 'Karlskrona', '7 - Möllebacken m.fl.', 'OG', '0'],
#  ['Blekinge län', 'Karlskrona', '8 - Pantarholmen', 'S', '444'],
#  ['Blekinge län', 'Karlskrona', '8 - Pantarholmen', 'SD', '253'],
#  ['Blekinge län', 'Karlskrona', '8 - Pantarholmen', 'M', '217'],
#  ['Blekinge län', 'Karlskrona', '8 - Pantarholmen', 'L', '93'],
#  ['Blekinge län', 'Karlskrona', '8 - Pantarholmen', 'V', '75'],
#  ['Blekinge län', 'Karlskrona', '8 - Pantarholmen', 'C', '74'],
#  ['Blekinge län', 'Karlskrona', '8 - Pantarholmen', 'KD', '64'],
#  ['Blekinge län', 'Karlskrona', '8 - Pantarholmen', 'MP', '43'],
#  ['Blekinge län', 'Karlskrona', '8 - Pantarholmen', 'ÖVR', '13'],
#  ['Blekinge län', 'Karlskrona', '8 - Pantarholmen', 'BLANK', '8'],
#  ['Blekinge län', 'Karlskrona', '8 - Pantarholmen', 'FI', '4'],
#  ['Blekinge län', 'Karlskrona', '8 - Pantarholmen', 'OGEJ', '0'],
#  ['Blekinge län', 'Karlskrona', '8 - Pantarholmen', 'OG', '0'],
#  ['Blekinge län', 'Karlskrona', '9 - Rosenfeldt m.fl.', 'S', '391'],
#  ['Blekinge län', 'Karlskrona', '9 - Rosenfeldt m.fl.', 'M', '285'],
#  ['Blekinge län', 'Karlskrona', '9 - Rosenfeldt m.fl.', 'SD', '223'],
#  ['Blekinge län', 'Karlskrona', '9 - Rosenfeldt m.fl.', 'L', '97'],
#  ['Blekinge län', 'Karlskrona', '9 - Rosenfeldt m.fl.', 'V', '85'],
#  ['Blekinge län', 'Karlskrona', '9 - Rosenfeldt m.fl.', 'KD', '83'],
#  ['Blekinge län', 'Karlskrona', '9 - Rosenfeldt m.fl.', 'C', '77'],
#  ['Blekinge län', 'Karlskrona', '9 - Rosenfeldt m.fl.', 'MP', '57'],
#  ['Blekinge län', 'Karlskrona', '9 - Rosenfeldt m.fl.', 'ÖVR', '18'],
#  ['Blekinge län', 'Karlskrona', '9 - Rosenfeldt m.fl.', 'BLANK', '14'],
#  ['Blekinge län', 'Karlskrona', '9 - Rosenfeldt m.fl.', 'FI', '8'],
#  ['Blekinge län', 'Karlskrona', '9 - Rosenfeldt m.fl.', 'OGEJ', '1'],
#  ['Blekinge län', 'Karlskrona', '9 - Rosenfeldt m.fl.', 'OG', '1'],
#  ['Blekinge län', 'Olofström', '0 - Brännaregården-Gränum norra', 'S', '292'],
#  ['Blekinge län', 'Olofström', '0 - Brännaregården-Gränum norra', 'SD', '273'],
#  ['Blekinge län', 'Olofström', '0 - Brännaregården-Gränum norra', 'M', '108'],
#  ['Blekinge län', 'Olofström', '0 - Brännaregården-Gränum norra', 'C', '57'],
#  ['Blekinge län', 'Olofström', '0 - Brännaregården-Gränum norra', 'KD', '42'],
#  ['Blekinge län', 'Olofström', '0 - Brännaregården-Gränum norra', 'V', '37'],
#  ['Blekinge län', 'Olofström', '0 - Brännaregården-Gränum norra', 'L', '16'],
#  ['Blekinge län',
#   'Olofström',
#   '0 - Brännaregården-Gränum norra',
#   'BLANK',
#   '12'],
#  ['Blekinge län', 'Olofström', '0 - Brännaregården-Gränum norra', 'MP', '10'],
#  ['Blekinge län', 'Olofström', '0 - Brännaregården-Gränum norra', 'ÖVR', '10'],
#  ['Blekinge län', 'Olofström', '0 - Brännaregården-Gränum norra', 'FI', '0'],
#  ['Blekinge län', 'Olofström', '0 - Brännaregården-Gränum norra', 'OGEJ', '0'],
#  ['Blekinge län', 'Olofström', '0 - Brännaregården-Gränum norra', 'OG', '0'],
#  ['Blekinge län', 'Olofström', '1 - Ekeryd', 'S', '342'],
#  ['Blekinge län', 'Olofström', '1 - Ekeryd', 'SD', '162'],
#  ['Blekinge län', 'Olofström', '1 - Ekeryd', 'M', '44'],
#  ['Blekinge län', 'Olofström', '1 - Ekeryd', 'V', '36'],
#  ['Blekinge län', 'Olofström', '1 - Ekeryd', 'C', '18'],
#  ['Blekinge län', 'Olofström', '1 - Ekeryd', 'L', '15'],
#  ['Blekinge län', 'Olofström', '1 - Ekeryd', 'KD', '13'],
#  ['Blekinge län', 'Olofström', '1 - Ekeryd', 'MP', '12'],
#  ['Blekinge län', 'Olofström', '1 - Ekeryd', 'BLANK', '7'],
#  ['Blekinge län', 'Olofström', '1 - Ekeryd', 'ÖVR', '4'],
#  ['Blekinge län', 'Olofström', '1 - Ekeryd', 'FI', '1'],
#  ['Blekinge län', 'Olofström', '1 - Ekeryd', 'OG', '1'],
#  ['Blekinge län', 'Olofström', '1 - Ekeryd', 'OGEJ', '0'],
#  ['Blekinge län', 'Olofström', '2 - Jämshög-Gränum södra', 'S', '548'],
#  ['Blekinge län', 'Olofström', '2 - Jämshög-Gränum södra', 'SD', '499'],
#  ['Blekinge län', 'Olofström', '2 - Jämshög-Gränum södra', 'M', '221'],
#  ['Blekinge län', 'Olofström', '2 - Jämshög-Gränum södra', 'C', '128'],
#  ['Blekinge län', 'Olofström', '2 - Jämshög-Gränum södra', 'V', '95'],
#  ['Blekinge län', 'Olofström', '2 - Jämshög-Gränum södra', 'KD', '85'],
#  ['Blekinge län', 'Olofström', '2 - Jämshög-Gränum södra', 'L', '42'],
#  ['Blekinge län', 'Olofström', '2 - Jämshög-Gränum södra', 'MP', '34'],
#  ['Blekinge län', 'Olofström', '2 - Jämshög-Gränum södra', 'BLANK', '17'],
#  ['Blekinge län', 'Olofström', '2 - Jämshög-Gränum södra', 'ÖVR', '16'],
#  ['Blekinge län', 'Olofström', '2 - Jämshög-Gränum södra', 'FI', '3'],
#  ['Blekinge län', 'Olofström', '2 - Jämshög-Gränum södra', 'OGEJ', '3'],
#  ['Blekinge län', 'Olofström', '2 - Jämshög-Gränum södra', 'OG', '0'],
#  ['Blekinge län', 'Olofström', '3 - Kyrkhult-Hemsjö', 'S', '398'],
#  ['Blekinge län', 'Olofström', '3 - Kyrkhult-Hemsjö', 'SD', '367'],
#  ['Blekinge län', 'Olofström', '3 - Kyrkhult-Hemsjö', 'M', '153'],
#  ['Blekinge län', 'Olofström', '3 - Kyrkhult-Hemsjö', 'C', '147'],
#  ['Blekinge län', 'Olofström', '3 - Kyrkhult-Hemsjö', 'KD', '83'],
#  ['Blekinge län', 'Olofström', '3 - Kyrkhult-Hemsjö', 'V', '62'],
#  ['Blekinge län', 'Olofström', '3 - Kyrkhult-Hemsjö', 'L', '26'],
#  ['Blekinge län', 'Olofström', '3 - Kyrkhult-Hemsjö', 'MP', '16'],
#  ['Blekinge län', 'Olofström', '3 - Kyrkhult-Hemsjö', 'BLANK', '14'],
#  ['Blekinge län', 'Olofström', '3 - Kyrkhult-Hemsjö', 'ÖVR', '12'],
#  ['Blekinge län', 'Olofström', '3 - Kyrkhult-Hemsjö', 'FI', '9'],
#  ['Blekinge län', 'Olofström', '3 - Kyrkhult-Hemsjö', 'OGEJ', '0'],
#  ['Blekinge län', 'Olofström', '3 - Kyrkhult-Hemsjö', 'OG', '0'],
#  ['Blekinge län', 'Olofström', '4 - Oredslund', 'S', '462'],
#  ['Blekinge län', 'Olofström', '4 - Oredslund', 'SD', '331'],
#  ['Blekinge län', 'Olofström', '4 - Oredslund', 'M', '167'],
#  ['Blekinge län', 'Olofström', '4 - Oredslund', 'C', '62'],
#  ['Blekinge län', 'Olofström', '4 - Oredslund', 'V', '62'],
#  ['Blekinge län', 'Olofström', '4 - Oredslund', 'KD', '52'],
#  ['Blekinge län', 'Olofström', '4 - Oredslund', 'L', '33'],
#  ['Blekinge län', 'Olofström', '4 - Oredslund', 'MP', '16'],
#  ['Blekinge län', 'Olofström', '4 - Oredslund', 'BLANK', '14'],
#  ['Blekinge län', 'Olofström', '4 - Oredslund', 'ÖVR', '7'],
#  ['Blekinge län', 'Olofström', '4 - Oredslund', 'FI', '2'],
#  ['Blekinge län', 'Olofström', '4 - Oredslund', 'OGEJ', '2'],
#  ['Blekinge län', 'Olofström', '4 - Oredslund', 'OG', '0'],
#  ['Blekinge län', 'Olofström', '5 - Petrefors', 'S', '490'],
#  ['Blekinge län', 'Olofström', '5 - Petrefors', 'SD', '349'],
#  ['Blekinge län', 'Olofström', '5 - Petrefors', 'M', '116'],
#  ['Blekinge län', 'Olofström', '5 - Petrefors', 'V', '74'],
#  ['Blekinge län', 'Olofström', '5 - Petrefors', 'KD', '60'],
#  ['Blekinge län', 'Olofström', '5 - Petrefors', 'C', '43'],
#  ['Blekinge län', 'Olofström', '5 - Petrefors', 'MP', '33'],
#  ['Blekinge län', 'Olofström', '5 - Petrefors', 'L', '19'],
#  ['Blekinge län', 'Olofström', '5 - Petrefors', 'BLANK', '14'],
#  ['Blekinge län', 'Olofström', '5 - Petrefors', 'ÖVR', '10'],
#  ['Blekinge län', 'Olofström', '5 - Petrefors', 'FI', '3'],
#  ['Blekinge län', 'Olofström', '5 - Petrefors', 'OG', '3'],
#  ['Blekinge län', 'Olofström', '5 - Petrefors', 'OGEJ', '0'],
#  ['Blekinge län', 'Olofström', '6 - Vilboken-Vilshult', 'S', '476'],
#  ['Blekinge län', 'Olofström', '6 - Vilboken-Vilshult', 'SD', '376'],
#  ['Blekinge län', 'Olofström', '6 - Vilboken-Vilshult', 'M', '164'],
#  ['Blekinge län', 'Olofström', '6 - Vilboken-Vilshult', 'V', '94'],
#  ['Blekinge län', 'Olofström', '6 - Vilboken-Vilshult', 'C', '80'],
#  ['Blekinge län', 'Olofström', '6 - Vilboken-Vilshult', 'KD', '68'],
#  ['Blekinge län', 'Olofström', '6 - Vilboken-Vilshult', 'L', '38'],
#  ['Blekinge län', 'Olofström', '6 - Vilboken-Vilshult', 'MP', '28'],
#  ['Blekinge län', 'Olofström', '6 - Vilboken-Vilshult', 'BLANK', '16'],
#  ['Blekinge län', 'Olofström', '6 - Vilboken-Vilshult', 'ÖVR', '14'],
#  ['Blekinge län', 'Olofström', '6 - Vilboken-Vilshult', 'FI', '1'],
#  ['Blekinge län', 'Olofström', '6 - Vilboken-Vilshult', 'OGEJ', '1'],
#  ['Blekinge län', 'Olofström', '6 - Vilboken-Vilshult', 'OG', '0'],
#  ['Blekinge län', 'Olofström', '7 - Uppsamlingsdistrikt', 'SD', '50'],
#  ['Blekinge län', 'Olofström', '7 - Uppsamlingsdistrikt', 'S', '46'],
#  ['Blekinge län', 'Olofström', '7 - Uppsamlingsdistrikt', 'M', '29'],
#  ['Blekinge län', 'Olofström', '7 - Uppsamlingsdistrikt', 'V', '12'],
#  ['Blekinge län', 'Olofström', '7 - Uppsamlingsdistrikt', 'MP', '11'],
#  ['Blekinge län', 'Olofström', '7 - Uppsamlingsdistrikt', 'C', '7'],
#  ['Blekinge län', 'Olofström', '7 - Uppsamlingsdistrikt', 'KD', '7'],
#  ['Blekinge län', 'Olofström', '7 - Uppsamlingsdistrikt', 'ÖVR', '5'],
#  ['Blekinge län', 'Olofström', '7 - Uppsamlingsdistrikt', 'L', '3'],
#  ['Blekinge län', 'Olofström', '7 - Uppsamlingsdistrikt', 'BLANK', '2'],
#  ['Blekinge län', 'Olofström', '7 - Uppsamlingsdistrikt', 'FI', '1'],
#  ['Blekinge län', 'Olofström', '7 - Uppsamlingsdistrikt', 'OGEJ', '0'],
#  ['Blekinge län', 'Olofström', '7 - Uppsamlingsdistrikt', 'OG', '0'],
#  ['Blekinge län', 'Ronneby', '0 - Backaryd-Öljehult', 'SD', '313'],
#  ['Blekinge län', 'Ronneby', '0 - Backaryd-Öljehult', 'S', '228'],
#  ['Blekinge län', 'Ronneby', '0 - Backaryd-Öljehult', 'M', '155'],
#  ['Blekinge län', 'Ronneby', '0 - Backaryd-Öljehult', 'C', '113'],
#  ['Blekinge län', 'Ronneby', '0 - Backaryd-Öljehult', 'KD', '61'],
#  ['Blekinge län', 'Ronneby', '0 - Backaryd-Öljehult', 'V', '59'],
#  ['Blekinge län', 'Ronneby', '0 - Backaryd-Öljehult', 'MP', '18'],
#  ['Blekinge län', 'Ronneby', '0 - Backaryd-Öljehult', 'L', '17'],
#  ['Blekinge län', 'Ronneby', '0 - Backaryd-Öljehult', 'BLANK', '13'],
#  ['Blekinge län', 'Ronneby', '0 - Backaryd-Öljehult', 'ÖVR', '8'],
#  ['Blekinge län', 'Ronneby', '0 - Backaryd-Öljehult', 'FI', '1'],
#  ['Blekinge län', 'Ronneby', '0 - Backaryd-Öljehult', 'OGEJ', '0'],
#  ['Blekinge län', 'Ronneby', '0 - Backaryd-Öljehult', 'OG', '0'],
#  ['Blekinge län', 'Ronneby', '10 - Hulta', 'S', '369'],
#  ['Blekinge län', 'Ronneby', '10 - Hulta', 'SD', '308'],
#  ['Blekinge län', 'Ronneby', '10 - Hulta', 'M', '232'],
#  ['Blekinge län', 'Ronneby', '10 - Hulta', 'C', '63'],
#  ['Blekinge län', 'Ronneby', '10 - Hulta', 'KD', '61'],
#  ['Blekinge län', 'Ronneby', '10 - Hulta', 'L', '53'],
#  ['Blekinge län', 'Ronneby', '10 - Hulta', 'V', '45'],
#  ['Blekinge län', 'Ronneby', '10 - Hulta', 'MP', '30'],
#  ['Blekinge län', 'Ronneby', '10 - Hulta', 'ÖVR', '16'],
#  ['Blekinge län', 'Ronneby', '10 - Hulta', 'BLANK', '4'],
#  ['Blekinge län', 'Ronneby', '10 - Hulta', 'FI', '3'],
#  ['Blekinge län', 'Ronneby', '10 - Hulta', 'OGEJ', '0'],
#  ['Blekinge län', 'Ronneby', '10 - Hulta', 'OG', '0'],
#  ['Blekinge län', 'Ronneby', '11 - Häggatorp', 'SD', '374'],
#  ['Blekinge län', 'Ronneby', '11 - Häggatorp', 'S', '311'],
#  ['Blekinge län', 'Ronneby', '11 - Häggatorp', 'M', '85'],
#  ['Blekinge län', 'Ronneby', '11 - Häggatorp', 'KD', '45'],
#  ['Blekinge län', 'Ronneby', '11 - Häggatorp', 'C', '44'],
#  ['Blekinge län', 'Ronneby', '11 - Häggatorp', 'V', '37'],
#  ['Blekinge län', 'Ronneby', '11 - Häggatorp', 'L', '15'],
#  ['Blekinge län', 'Ronneby', '11 - Häggatorp', 'BLANK', '11'],
#  ['Blekinge län', 'Ronneby', '11 - Häggatorp', 'MP', '7'],
#  ['Blekinge län', 'Ronneby', '11 - Häggatorp', 'ÖVR', '5'],
#  ['Blekinge län', 'Ronneby', '11 - Häggatorp', 'FI', '3'],
#  ['Blekinge län', 'Ronneby', '11 - Häggatorp', 'OGEJ', '0'],
#  ['Blekinge län', 'Ronneby', '11 - Häggatorp', 'OG', '0'],
#  ['Blekinge län', 'Ronneby', '12 - Kalleberga', 'SD', '371'],
#  ['Blekinge län', 'Ronneby', '12 - Kalleberga', 'S', '367'],
#  ['Blekinge län', 'Ronneby', '12 - Kalleberga', 'M', '141'],
#  ['Blekinge län', 'Ronneby', '12 - Kalleberga', 'V', '60'],
#  ['Blekinge län', 'Ronneby', '12 - Kalleberga', 'KD', '46'],
#  ['Blekinge län', 'Ronneby', '12 - Kalleberga', 'C', '27'],
#  ['Blekinge län', 'Ronneby', '12 - Kalleberga', 'L', '21'],
#  ['Blekinge län', 'Ronneby', '12 - Kalleberga', 'BLANK', '10'],
#  ['Blekinge län', 'Ronneby', '12 - Kalleberga', 'MP', '7'],
#  ['Blekinge län', 'Ronneby', '12 - Kalleberga', 'ÖVR', '6'],
#  ['Blekinge län', 'Ronneby', '12 - Kalleberga', 'OG', '1'],
#  ['Blekinge län', 'Ronneby', '12 - Kalleberga', 'FI', '0'],
#  ['Blekinge län', 'Ronneby', '12 - Kalleberga', 'OGEJ', '0'],
#  ['Blekinge län', 'Ronneby', '13 - Kallinge', 'S', '387'],
#  ['Blekinge län', 'Ronneby', '13 - Kallinge', 'SD', '372'],
#  ['Blekinge län', 'Ronneby', '13 - Kallinge', 'M', '94'],
#  ['Blekinge län', 'Ronneby', '13 - Kallinge', 'V', '53'],
#  ['Blekinge län', 'Ronneby', '13 - Kallinge', 'KD', '35'],
#  ['Blekinge län', 'Ronneby', '13 - Kallinge', 'C', '29'],
#  ['Blekinge län', 'Ronneby', '13 - Kallinge', 'L', '26'],
#  ['Blekinge län', 'Ronneby', '13 - Kallinge', 'BLANK', '11'],
#  ['Blekinge län', 'Ronneby', '13 - Kallinge', 'MP', '10'],
#  ['Blekinge län', 'Ronneby', '13 - Kallinge', 'ÖVR', '8'],
#  ['Blekinge län', 'Ronneby', '13 - Kallinge', 'FI', '2'],
#  ['Blekinge län', 'Ronneby', '13 - Kallinge', 'OG', '2'],
#  ['Blekinge län', 'Ronneby', '13 - Kallinge', 'OGEJ', '0'],
#  ['Blekinge län', 'Ronneby', '14 - Listerby S', 'SD', '200'],
#  ['Blekinge län', 'Ronneby', '14 - Listerby S', 'S', '167'],
#  ['Blekinge län', 'Ronneby', '14 - Listerby S', 'M', '132'],
#  ['Blekinge län', 'Ronneby', '14 - Listerby S', 'C', '53'],
#  ['Blekinge län', 'Ronneby', '14 - Listerby S', 'KD', '43'],
#  ['Blekinge län', 'Ronneby', '14 - Listerby S', 'V', '25'],
#  ['Blekinge län', 'Ronneby', '14 - Listerby S', 'L', '15'],
#  ['Blekinge län', 'Ronneby', '14 - Listerby S', 'MP', '12'],
#  ['Blekinge län', 'Ronneby', '14 - Listerby S', 'BLANK', '8'],
#  ['Blekinge län', 'Ronneby', '14 - Listerby S', 'ÖVR', '6'],
#  ['Blekinge län', 'Ronneby', '14 - Listerby S', 'FI', '3'],
#  ['Blekinge län', 'Ronneby', '14 - Listerby S', 'OGEJ', '0'],
#  ['Blekinge län', 'Ronneby', '14 - Listerby S', 'OG', '0'],
#  ['Blekinge län', 'Ronneby', '15 - Lugnet', 'S', '248'],
#  ['Blekinge län', 'Ronneby', '15 - Lugnet', 'SD', '243'],
#  ['Blekinge län', 'Ronneby', '15 - Lugnet', 'M', '163'],
#  ['Blekinge län', 'Ronneby', '15 - Lugnet', 'V', '64'],
#  ['Blekinge län', 'Ronneby', '15 - Lugnet', 'C', '57'],
#  ['Blekinge län', 'Ronneby', '15 - Lugnet', 'KD', '56'],
#  ['Blekinge län', 'Ronneby', '15 - Lugnet', 'L', '27'],
#  ['Blekinge län', 'Ronneby', '15 - Lugnet', 'MP', '25'],
#  ['Blekinge län', 'Ronneby', '15 - Lugnet', 'ÖVR', '12'],
#  ['Blekinge län', 'Ronneby', '15 - Lugnet', 'BLANK', '6'],
#  ['Blekinge län', 'Ronneby', '15 - Lugnet', 'FI', '1'],
#  ['Blekinge län', 'Ronneby', '15 - Lugnet', 'OGEJ', '1'],
#  ['Blekinge län', 'Ronneby', '15 - Lugnet', 'OG', '1'],
#  ['Blekinge län', 'Ronneby', '16 - Persborg', 'S', '343'],
#  ['Blekinge län', 'Ronneby', '16 - Persborg', 'SD', '299'],
#  ['Blekinge län', 'Ronneby', '16 - Persborg', 'M', '260'],
#  ['Blekinge län', 'Ronneby', '16 - Persborg', 'KD', '70'],
#  ['Blekinge län', 'Ronneby', '16 - Persborg', 'C', '63'],
#  ['Blekinge län', 'Ronneby', '16 - Persborg', 'L', '54'],
#  ['Blekinge län', 'Ronneby', '16 - Persborg', 'V', '53'],
#  ['Blekinge län', 'Ronneby', '16 - Persborg', 'MP', '25'],
#  ['Blekinge län', 'Ronneby', '16 - Persborg', 'BLANK', '12'],
#  ['Blekinge län', 'Ronneby', '16 - Persborg', 'FI', '9'],
#  ['Blekinge län', 'Ronneby', '16 - Persborg', 'ÖVR', '8'],
#  ['Blekinge län', 'Ronneby', '16 - Persborg', 'OG', '3'],
#  ...]

# %% [markdown]
# ---
# #### Local Test for Assignment 1, PROBLEM 3
# Evaluate cell below to make sure your answer is valid.                             You **should not** modify anything in the cell below when evaluating it to do a local test of                             your solution.
# You may need to include and evaluate code snippets from lecture notebooks in cells above to make the local test work correctly sometimes (see error messages for clues). This is meant to help you become efficient at recalling materials covered in lectures that relate to this problem. Such local tests will generally not be available in the exam.

# %%
# Evaluate this cell locally to make sure you have the answer in the right format
try:
    assert(type(header) == list)
    print("Good! You have the header as a list. Hopefully it is the correct!")
except AssertionError:
    print("Try Again. You should answer with a list.")
try:
    types = set([type(a) for a in header])
    assert((len(types) == 1) and (list(types)[0] == str))
    print("Good! You have the header as a list of strings. Hopefully it is the correct!")
except AssertionError:
    print("Try Again. You should answer with a list of strings.")
try:
    assert(type(data) == list)
    print("Good! You have the data as a list. Hopefully it is the correct!")
except AssertionError:
    print("Try Again. You should answer with a list.")
try:
    types = set([type(a) for a in data])
    assert((len(types) == 1) and (list(types)[0] == list))
    print("Good! You have the data as a list of lists. Hopefully it is the correct!")
except AssertionError:
    print("Try Again. You should answer with a list of lists.")
try:
    types = set(sum([[type(d) for d in t] for t in data[:1]],[]))
    assert((len(types) == 1) and (list(types)[0] == str))
    print("Good! You have the data as a list of lists of strings. Hopefully it is the correct!")
except AssertionError:
    print("Try Again. You should answer with a list of lists of strings.")
# Out:
# Good! You have the header as a list. Hopefully it is the correct!
# Good! You have the header as a list of strings. Hopefully it is the correct!
# Good! You have the data as a list. Hopefully it is the correct!
# Good! You have the data as a list of lists. Hopefully it is the correct!
# Good! You have the data as a list of lists of strings. Hopefully it is the correct!

# %% [markdown]
# ---
# ## Assignment 1, PROBLEM 4
# Maximum Points = 8

# %% [markdown]
# ## Students passing exam (Sample exam problem)
# Let's say we have an exam question which consists of $10$ yes/no questions.
# From past performance of similar students, a randomly chosen student will know the correct answer to $N \sim \text{binom}(10,6/10)$ questions. Furthermore, we assume that the student will guess the answer with equal probability to each question they don't know the answer to, i.e. given $N$ we define $Z \sim \text{binom}(10-N,1/2)$ as the number of correctly guessed answers. Define $Y = N + Z$, i.e., $Y$ represents the number of total correct answers.
#
# We are interested in setting a deterministic threshold $T$, i.e., we would pass a student at threshold $T$ if $Y \geq T$. Here $T \in \{0,1,2,\ldots,10\}$.
#
# 1. [5p] For each threshold $T$, compute the probability that the student *knows* less than $5$ correct answers given that the student passed, i.e., $N < 5$. Put the answer in `problem11_probabilities` as a list.
# 2. [3p] What is the smallest value of $T$ such that if $Y \geq T$ then we are 90\% certain that $N \geq 5$?

# %%
from scipy.special import binom as binomial
from scipy.stats import binom as binomial_pmf

n_questions = 10
p_know = 6/10
p_guess = 1/2
p_N = lambda k: binomial(n_questions,k)*((1-p_know)**(n_questions-k))*((p_know)**k) # the PMF of N is p_N(k) where p_N is

def prob_Y_given_N(y,k):
    return binomial_pmf.pmf(y - k, n_questions - k, p_guess)

def prob_Y(y):
    return sum(p_N(k) * prob_Y_given_N(y,k) for k in range(n_questions+1))

def prob_Y_geq_T(T):
    return sum(prob_Y(y) for y in range(T, n_questions+1))

def prob_N_given_Y(T):
    prob = 0
    for k in range(5):
        for y in range(T, n_questions+1):
            prob += p_N(k) * prob_Y_given_N(y,k)
    return prob

problem11_probabilities = []

for T in range(n_questions+1):
    p_N_given_Y = prob_N_given_Y(T)
    p_Y_geq_T = prob_Y_geq_T(T)
    if p_Y_geq_T > 0:
        cond_prob = p_N_given_Y / p_Y_geq_T
    else:
        cond_prob = 0
    problem11_probabilities.append(cond_prob)

problem11_probabilities
# Out:
# [0.16623861760000005,
#  0.16623853222282575,
#  0.16623511712151576,
#  0.16617364051358016,
#  0.16551732549063342,
#  0.16089403080809417,
#  0.14445279891451648,
#  0.11223025722358063,
#  0.07321212315323332,
#  0.040584564208984396,
#  0.0197277069091797]

# %%
# Part 1: 
# replace XXX to represent P(N < 5) for T = [0,1,2,...,10], i.e. your answer should be a list
# of length 11.
problem11_probabilities = [0.16623861760000005,
 0.16623853222282575,
 0.16623511712151576,
 0.16617364051358016,
 0.16551732549063342,
 0.16089403080809417,
 0.14445279891451648,
 0.11223025722358063,
 0.07321212315323332,
 0.040584564208984396,
 0.0197277069091797]

# %%
# Part 2: Give an integer between 0 and 10 which is the answer to 2.
problem12_T = 8

# %% [markdown]
# ---
# ## Assignment 1, PROBLEM 5
# Maximum Points = 8

# %% [markdown]
# ## Concentration of measure (Sample exam problem)
#
# As you recall, we said that concentration of measure was simply the phenomenon where we expect that the probability of a large deviation of some quantity becoming smaller as we observe more samples: [0.4 points per correct answer]
#
# 1. Which of the following will exponentially concentrate, i.e. for some $C_1,C_2,C_3,C_4 $
# $$
#     P(Z - \mathbb{E}[Z] \geq \epsilon) \leq C_1 e^{-C_2 n \epsilon^2} \vee C_3 e^{-C_4 n (\epsilon+1)} \enspace .
# $$
#
#     1. The empirical variance of i.i.d. random variables with finite mean?
#     2. The empirical variance of i.i.d. sub-Gaussian random variables?
#     3. The empirical variance of i.i.d. sub-Exponential random variables?
#     4. The empirical mean of i.i.d. sub-Gaussian random variables?
#     5. The empirical mean of i.i.d. sub-Exponential random variables?
#     6. The empirical mean of i.i.d. random variables with finite variance?
#     7. The empirical third moment of i.i.d. random variables with finite sixth moment?
#     8. The empirical fourth moment of i.i.d. sub-Gaussian random variables?
#     9. The empirical mean of i.i.d. deterministic random variables?
#     10. The empirical tenth moment of i.i.d. Bernoulli random variables?
#
# 2. Which of the above will concentrate in the weaker sense, that for some $C_1$
# $$
#     P(Z - \mathbb{E}[Z] \geq \epsilon) \leq \frac{C_1}{n \epsilon^2}?
# $$

# %%
# Answers to part 1, which of the alternatives exponentially concentrate, answer as a list
# i.e. [1,4,5] that is example 1, 4, and 5 concentrate
problem3_answer_1 = [XXX]

# %%
# Answers to part 2, which of the alternatives concentrate in the weaker sense, answer as a list
# i.e. [1,4,5] that is example 1, 4, and 5 concentrate
problem3_answer_2 = [XXX]
